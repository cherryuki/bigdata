# %% [markdown]
# **21-03-24 ML_DL 08_DNN 심장병발병예측 (c)cherryuki (ji)**

# %% [markdown]
# # 08. DNN_심장병 발병예측
# ### DNN: Deep Neural Network

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# %%
#1. 데이터셋 생성
raw_data = pd.read_excel('data/heart-disease.xlsx')
raw_data.head()
# Out:
#    age  sex  cp  treshtbps chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1        145  233    1        2      150      0      2.3      3
# 1   67    1   4        160  286    0        0      108      1      1.5      2
# 2   67    1   4        120    ?    0        2      129      1      2.6      2
# 3   37    1   3        130  250    0        0      187      0      3.5      3
# 4   41    0   2        130  204    0        2      172      0      1.4      1
#
#   ca hsl  heartDisease
# 0  0   6             0
# 1  3   3             1
# 2  2   7             1
# 3  0   3             0
# 4  0   3             0

# %%
raw_data.describe()
# Out:
#               age         sex          cp   treshtbps         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769    0.148515    0.983498
# std      9.038662    0.467299    0.960126   17.599748    0.356198    0.994883
# min     29.000000    0.000000    1.000000   94.000000    0.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000    0.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000    0.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000    0.000000    2.000000
# max     77.000000    1.000000    4.000000  200.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope  heartDisease
# count  303.000000  303.000000  303.000000  303.000000    303.000000
# mean   149.607261    0.326733    1.039604    1.600660      0.458746
# std     22.875003    0.469794    1.161075    0.616226      0.499120
# min     71.000000    0.000000    0.000000    1.000000      0.000000
# 25%    133.500000    0.000000    0.000000    1.000000      0.000000
# 50%    153.000000    0.000000    0.800000    2.000000      0.000000
# 75%    166.000000    1.000000    1.600000    2.000000      1.000000
# max    202.000000    1.000000    6.200000    3.000000      1.000000

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           303 non-null    int64
#  1   sex           303 non-null    int64
#  2   cp            303 non-null    int64
#  3   treshtbps     303 non-null    int64
#  4   chol          303 non-null    object
#  5   fbs           303 non-null    int64
#  6   restecg       303 non-null    int64
#  7   thalach       303 non-null    int64
#  8   exang         303 non-null    int64
#  9   oldpeak       303 non-null    float64
#  10  slope         303 non-null    int64
#  11  ca            303 non-null    object
#  12  hsl           303 non-null    object
#  13  heartDisease  303 non-null    int64
# dtypes: float64(1), int64(10), object(3)
# memory usage: 33.3+ KB

# %%
raw_data[raw_data['chol']=='?']
# Out:
#    age  sex  cp  treshtbps chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 2   67    1   4        120    ?    0        2      129      1      2.6      2
#
#   ca hsl  heartDisease
# 2  2   7             1

# %%
raw_data[raw_data['ca']=='?']
# Out:
#      age  sex  cp  treshtbps chol  fbs  restecg  thalach  exang  oldpeak  \
# 166   52    1   3        138  223    0        0      169      0      0.0
# 192   43    1   4        132  247    1        2      143      1      0.1
# 287   58    1   2        125  220    0        0      144      0      0.4
# 302   38    1   3        138  175    0        0      173      0      0.0
#
#      slope ca hsl  heartDisease
# 166      1  ?   3             0
# 192      2  ?   7             1
# 287      2  ?   7             0
# 302      1  ?   3             0

# %%
raw_data[raw_data['hsl']=='?']
# Out:
#      age  sex  cp  treshtbps chol  fbs  restecg  thalach  exang  oldpeak  \
# 87    53    0   3        128  216    0        2      115      0      0.0
# 266   52    1   4        128  204    1        0      156      1      1.0
#
#      slope ca hsl  heartDisease
# 87       1  0   ?             0
# 266      2  0   ?             1

# %%
clean_data = raw_data.replace('?', np.nan)
clean_data
# Out:
#      age  sex  cp  treshtbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1        145  233.0    1        2      150      0      2.3
# 1     67    1   4        160  286.0    0        0      108      1      1.5
# 2     67    1   4        120    NaN    0        2      129      1      2.6
# 3     37    1   3        130  250.0    0        0      187      0      3.5
# 4     41    0   2        130  204.0    0        2      172      0      1.4
# ..   ...  ...  ..        ...    ...  ...      ...      ...    ...      ...
# 298   45    1   1        110  264.0    0        0      132      0      1.2
# 299   68    1   4        144  193.0    1        0      141      0      3.4
# 300   57    1   4        130  131.0    0        0      115      1      1.2
# 301   57    0   2        130  236.0    0        2      174      0      0.0
# 302   38    1   3        138  175.0    0        0      173      0      0.0
#
#      slope   ca  hsl  heartDisease
# 0        3  0.0  6.0             0
# 1        2  3.0  3.0             1
# 2        2  2.0  7.0             1
# 3        3  0.0  3.0             0
# 4        1  0.0  3.0             0
# ..     ...  ...  ...           ...
# 298      2  0.0  7.0             1
# 299      2  2.0  7.0             1
# 300      2  1.0  7.0             1
# 301      2  1.0  3.0             1
# 302      1  NaN  3.0             0
#
# [303 rows x 14 columns]

# %%
clean_data = clean_data.dropna() #NAN값이 있는 row를 제거
clean_data
# Out:
#      age  sex  cp  treshtbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1        145  233.0    1        2      150      0      2.3
# 1     67    1   4        160  286.0    0        0      108      1      1.5
# 3     37    1   3        130  250.0    0        0      187      0      3.5
# 4     41    0   2        130  204.0    0        2      172      0      1.4
# 5     56    1   2        120  236.0    0        0      178      0      0.8
# ..   ...  ...  ..        ...    ...  ...      ...      ...    ...      ...
# 297   57    0   4        140  241.0    0        0      123      1      0.2
# 298   45    1   1        110  264.0    0        0      132      0      1.2
# 299   68    1   4        144  193.0    1        0      141      0      3.4
# 300   57    1   4        130  131.0    0        0      115      1      1.2
# 301   57    0   2        130  236.0    0        2      174      0      0.0
#
#      slope   ca  hsl  heartDisease
# 0        3  0.0  6.0             0
# 1        2  3.0  3.0             1
# 3        3  0.0  3.0             0
# 4        1  0.0  3.0             0
# 5        1  0.0  3.0             0
# ..     ...  ...  ...           ...
# 297      2  0.0  7.0             1
# 298      2  0.0  7.0             1
# 299      2  2.0  7.0             1
# 300      2  1.0  7.0             1
# 301      2  1.0  3.0             1
#
# [296 rows x 14 columns]

# %%
clean_data.isnull().sum()
# Out:
# age             0
# sex             0
# cp              0
# treshtbps       0
# chol            0
# fbs             0
# restecg         0
# thalach         0
# exang           0
# oldpeak         0
# slope           0
# ca              0
# hsl             0
# heartDisease    0
# dtype: int64

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 296 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           296 non-null    int64
#  1   sex           296 non-null    int64
#  2   cp            296 non-null    int64
#  3   treshtbps     296 non-null    int64
#  4   chol          296 non-null    float64
#  5   fbs           296 non-null    int64
#  6   restecg       296 non-null    int64
#  7   thalach       296 non-null    int64
#  8   exang         296 non-null    int64
#  9   oldpeak       296 non-null    float64
#  10  slope         296 non-null    int64
#  11  ca            296 non-null    float64
#  12  hsl           296 non-null    float64
#  13  heartDisease  296 non-null    int64
# dtypes: float64(4), int64(10)
# memory usage: 34.7 KB

# %%
clean_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'treshtbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'hsl', 'heartDisease'],
#       dtype='object')

# %%
Input_data = clean_data.iloc[:, :-1]
Target = clean_data.iloc[:, [-1]]
Target
# Out:
#      heartDisease
# 0               0
# 1               1
# 3               0
# 4               0
# 5               0
# ..            ...
# 297             1
# 298             1
# 299             1
# 300             1
# 301             1
#
# [296 rows x 1 columns]

# %%
#심장별 걸린 데이터 수
Target['heartDisease'].sum()
# Out:
# 136

# %%
#심장병 걸린 데이터 비율
Target['heartDisease'].mean()
# Out:
# 0.4594594594594595

# %%
Input_data.head(2)
# Out:
#    age  sex  cp  treshtbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    1   1        145  233.0    1        2      150      0      2.3
# 1   67    1   4        160  286.0    0        0      108      1      1.5
#
#    slope   ca  hsl
# 0      3  0.0  6.0
# 1      2  3.0  3.0

# %%
#scale 조정
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(Input_data)
scaled_input = scaler.transform(Input_data)
scaled_input = pd.DataFrame(scaled_input)
scaled_input
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.942285  0.692820 -2.236793  0.747441 -0.277228  2.425638  1.020526
# 1    1.385714  0.692820  0.876486  1.592523  0.742265 -0.412263 -0.993312
# 2   -1.939999  0.692820 -0.161274 -0.097641  0.049779 -0.412263 -0.993312
# 3   -1.496571 -1.443376 -1.199033 -0.097641 -0.835064 -0.412263  1.020526
# 4    0.166286  0.692820 -1.199033 -0.661029 -0.219521 -0.412263 -0.993312
# ..        ...       ...       ...       ...       ...       ...       ...
# 291  0.277143 -1.443376  0.876486  0.465747 -0.123343 -0.412263 -0.993312
# 292 -1.053142  0.692820 -2.236793 -1.224417  0.319079 -0.412263 -0.993312
# 293  1.496571  0.692820  0.876486  0.691102 -1.046657  2.425638 -0.993312
# 294  0.277143  0.692820  0.876486 -0.097641 -2.239272 -0.412263 -0.993312
# 295  0.277143 -1.443376 -1.199033 -0.097641 -0.219521 -0.412263  1.020526
#
#            7         8         9         10        11        12
# 0    0.014451 -0.692820  1.074839  2.264087 -0.718421  0.660262
# 1   -1.818794  1.443376  0.386756  0.645320  2.487397 -0.890830
# 2    1.629453 -0.692820  2.106963  2.264087 -0.718421 -0.890830
# 3    0.974723 -0.692820  0.300746 -0.973448 -0.718421 -0.890830
# 4    1.236615 -0.692820 -0.215316 -0.973448 -0.718421 -0.890830
# ..        ...       ...       ...       ...       ...       ...
# 291 -1.164064  1.443376 -0.731379  0.645320 -0.718421  1.177293
# 292 -0.771225 -0.692820  0.128725  0.645320 -0.718421  1.177293
# 293 -0.378387 -0.692820  2.020953  0.645320  1.418791  1.177293
# 294 -1.513253  1.443376  0.128725  0.645320  0.350185  1.177293
# 295  1.062020 -0.692820 -0.903399  0.645320  0.350185 -0.890830
#
# [296 rows x 13 columns]

# %%
scaled_input.describe().T #평균 0, 표준편차 1에 가깝게 scale 조정 됨(StandardScaler)
# Out:
#     count          mean       std       min       25%       50%       75%  \
# 0   296.0  4.500904e-18  1.001693 -2.826856 -0.720571  0.166286  0.720571
# 1   296.0  2.850573e-17  1.001693 -1.443376 -1.443376  0.692820  0.692820
# 2   296.0  1.200241e-16  1.001693 -2.236793 -0.161274 -0.161274  0.876486
# 3   296.0  6.067781e-16  1.001693 -2.125838 -0.661029 -0.097641  0.465747
# 4   296.0  1.997276e-17  1.001693 -2.335451 -0.700414 -0.084871  0.554717
# 5   296.0  7.501507e-19  1.001693 -0.412263 -0.412263 -0.412263 -0.412263
# 6   296.0  2.182939e-16  1.001693 -0.993312 -0.993312 -0.489853  1.020526
# 7   296.0  6.458797e-16  1.001693 -3.433796 -0.694840  0.145397  0.712830
# 8   296.0  5.926190e-17  1.001693 -0.692820 -0.692820 -0.692820  1.443376
# 9   296.0 -7.951597e-17  1.001693 -0.903399 -0.903399 -0.215316  0.472766
# 10  296.0  1.155232e-16  1.001693 -0.973448 -0.973448  0.645320  0.645320
# 11  296.0  6.526311e-17  1.001693 -0.718421 -0.718421 -0.718421  0.350185
# 12  296.0 -2.663035e-17  1.001693 -0.890830 -0.890830 -0.890830  1.177293
#
#          max
# 0   2.494285
# 1   0.692820
# 2   0.876486
# 3   3.846075
# 4   6.089796
# 5   2.425638
# 6   1.020526
# 7   2.284183
# 8   1.443376
# 9   4.429243
# 10  2.264087
# 11  2.487397
# 12  1.177293

# %%
# 학습 데이터:테스트 데이터 = 7:3 으로 나누기
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(scaled_input, Target,
                                                   test_size=0.3, random_state=5) #seed값 세팅과 유사
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (207, 13) (207, 1) (89, 13) (89, 1)

# %%
#2. 모델 구성
model = Sequential()
model.add(Dense(units=500, input_dim=13, activation='tanh'))
#과적합을 해결하기 위한 Dropout
model.add(Dropout(0.1))
model.add(Dense(units=200, activation='tanh'))
model.add(Dropout(0.1))
model.add(Dense(units=100, activation='tanh'))
model.add(Dropout(0.1))
model.add(Dense(units=1, activation='sigmoid')) #이진분류 (0아니면1)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               7000
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               100200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 127,401
# Trainable params: 127,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **<metrics에 들어갈 수 있는 항목들; 성능평가지표>**
# - accuracy(정확도); 예측값과 실제값이 동일한 건수 / 전체 건수 (TP+TN / TP+FN+FP+TN)
# - Recall(재현율); 실제 True를 True라고 예측한 건수 / 실제 True인 전체 건수 (TP / TP+FN)
# - Precision(정밀도); 실제 True를 True라고 예측한 건수 / True로 예측한 전체 건수 (TP / TP+FP)

# %%
#3. 학습과정 설정
from tensorflow.keras import metrics
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
#model.compile(loss='categorical_crossentropy', optimizer='nadam', 
#                 metrics=[metrics.Recall()]) 
#metrics에 들어갈 수 있는 것들 - accuracy, Recall, Precision

# %%
#4. 학습 시키기
hist = model.fit(X_train, Y_train, epochs=50, batch_size=50,
                validation_split=0.2, verbose=2)
#validation_split; train 데이터에서 일부(0.2)를 검증데이터로 사용
##(검증 데이터셋 없을 경우 사용하는 방법)
# Out:
# Epoch 1/50
# 4/4 - 0s - loss: 0.0357 - accuracy: 0.9697 - val_loss: 0.1515 - val_accuracy: 0.8095
# Epoch 2/50
# 4/4 - 0s - loss: 0.0353 - accuracy: 0.9636 - val_loss: 0.1429 - val_accuracy: 0.8333
# Epoch 3/50
# 4/4 - 0s - loss: 0.0319 - accuracy: 0.9758 - val_loss: 0.1414 - val_accuracy: 0.8095
# Epoch 4/50
# 4/4 - 0s - loss: 0.0312 - accuracy: 0.9758 - val_loss: 0.1477 - val_accuracy: 0.7857
# Epoch 5/50
# 4/4 - 0s - loss: 0.0302 - accuracy: 0.9818 - val_loss: 0.1584 - val_accuracy: 0.7857
# Epoch 6/50
# 4/4 - 0s - loss: 0.0306 - accuracy: 0.9818 - val_loss: 0.1598 - val_accuracy: 0.7619
# Epoch 7/50
# 4/4 - 0s - loss: 0.0279 - accuracy: 0.9758 - val_loss: 0.1466 - val_accuracy: 0.8095
# Epoch 8/50
# 4/4 - 0s - loss: 0.0300 - accuracy: 0.9818 - val_loss: 0.1408 - val_accuracy: 0.8095
# Epoch 9/50
# 4/4 - 0s - loss: 0.0277 - accuracy: 0.9758 - val_loss: 0.1387 - val_accuracy: 0.8095
# Epoch 10/50
# 4/4 - 0s - loss: 0.0266 - accuracy: 0.9818 - val_loss: 0.1437 - val_accuracy: 0.8095
# Epoch 11/50
# 4/4 - 0s - loss: 0.0267 - accuracy: 0.9818 - val_loss: 0.1524 - val_accuracy: 0.8095
# Epoch 12/50
# 4/4 - 0s - loss: 0.0259 - accuracy: 0.9818 - val_loss: 0.1607 - val_accuracy: 0.7857
# Epoch 13/50
# 4/4 - 0s - loss: 0.0248 - accuracy: 0.9818 - val_loss: 0.1659 - val_accuracy: 0.7857
# Epoch 14/50
# 4/4 - 0s - loss: 0.0246 - accuracy: 0.9818 - val_loss: 0.1528 - val_accuracy: 0.7857
# Epoch 15/50
# 4/4 - 0s - loss: 0.0239 - accuracy: 0.9818 - val_loss: 0.1425 - val_accuracy: 0.8095
# Epoch 16/50
# 4/4 - 0s - loss: 0.0206 - accuracy: 0.9818 - val_loss: 0.1385 - val_accuracy: 0.8333
# Epoch 17/50
# 4/4 - 0s - loss: 0.0225 - accuracy: 0.9818 - val_loss: 0.1407 - val_accuracy: 0.8333
# Epoch 18/50
# 4/4 - 0s - loss: 0.0234 - accuracy: 0.9818 - val_loss: 0.1502 - val_accuracy: 0.7857
# Epoch 19/50
# 4/4 - 0s - loss: 0.0202 - accuracy: 0.9818 - val_loss: 0.1588 - val_accuracy: 0.7857
# Epoch 20/50
# 4/4 - 0s - loss: 0.0196 - accuracy: 0.9818 - val_loss: 0.1616 - val_accuracy: 0.7857
# Epoch 21/50
# 4/4 - 0s - loss: 0.0185 - accuracy: 0.9879 - val_loss: 0.1489 - val_accuracy: 0.8095
# Epoch 22/50
# 4/4 - 0s - loss: 0.0195 - accuracy: 0.9818 - val_loss: 0.1437 - val_accuracy: 0.8333
# Epoch 23/50
# 4/4 - 0s - loss: 0.0211 - accuracy: 0.9818 - val_loss: 0.1421 - val_accuracy: 0.8333
# Epoch 24/50
# 4/4 - 0s - loss: 0.0191 - accuracy: 0.9818 - val_loss: 0.1437 - val_accuracy: 0.8095
# Epoch 25/50
# 4/4 - 0s - loss: 0.0175 - accuracy: 0.9879 - val_loss: 0.1433 - val_accuracy: 0.8095
# Epoch 26/50
# 4/4 - 0s - loss: 0.0178 - accuracy: 0.9879 - val_loss: 0.1417 - val_accuracy: 0.8095
# Epoch 27/50
# 4/4 - 0s - loss: 0.0192 - accuracy: 0.9818 - val_loss: 0.1366 - val_accuracy: 0.8333
# Epoch 28/50
# 4/4 - 0s - loss: 0.0189 - accuracy: 0.9879 - val_loss: 0.1295 - val_accuracy: 0.8571
# Epoch 29/50
# 4/4 - 0s - loss: 0.0185 - accuracy: 0.9879 - val_loss: 0.1249 - val_accuracy: 0.8810
# Epoch 30/50
# 4/4 - 0s - loss: 0.0215 - accuracy: 0.9818 - val_loss: 0.1265 - val_accuracy: 0.8810
# Epoch 31/50
# 4/4 - 0s - loss: 0.0188 - accuracy: 0.9758 - val_loss: 0.1373 - val_accuracy: 0.8333
# Epoch 32/50
# 4/4 - 0s - loss: 0.0181 - accuracy: 0.9818 - val_loss: 0.1470 - val_accuracy: 0.8333
# Epoch 33/50
# 4/4 - 0s - loss: 0.0180 - accuracy: 0.9818 - val_loss: 0.1566 - val_accuracy: 0.7857
# Epoch 34/50
# 4/4 - 0s - loss: 0.0174 - accuracy: 0.9879 - val_loss: 0.1537 - val_accuracy: 0.7857
# Epoch 35/50
# 4/4 - 0s - loss: 0.0159 - accuracy: 0.9879 - val_loss: 0.1473 - val_accuracy: 0.8333
# Epoch 36/50
# 4/4 - 0s - loss: 0.0156 - accuracy: 0.9879 - val_loss: 0.1413 - val_accuracy: 0.8333
# Epoch 37/50
# 4/4 - 0s - loss: 0.0155 - accuracy: 0.9879 - val_loss: 0.1395 - val_accuracy: 0.8333
# Epoch 38/50
# 4/4 - 0s - loss: 0.0150 - accuracy: 0.9879 - val_loss: 0.1383 - val_accuracy: 0.8571
# Epoch 39/50
# 4/4 - 0s - loss: 0.0152 - accuracy: 0.9879 - val_loss: 0.1385 - val_accuracy: 0.8333
# Epoch 40/50
# 4/4 - 0s - loss: 0.0164 - accuracy: 0.9818 - val_loss: 0.1400 - val_accuracy: 0.8333
# Epoch 41/50
# 4/4 - 0s - loss: 0.0159 - accuracy: 0.9879 - val_loss: 0.1414 - val_accuracy: 0.8333
# Epoch 42/50
# 4/4 - 0s - loss: 0.0143 - accuracy: 0.9879 - val_loss: 0.1392 - val_accuracy: 0.8333
# Epoch 43/50
# 4/4 - 0s - loss: 0.0147 - accuracy: 0.9879 - val_loss: 0.1363 - val_accuracy: 0.8571
# Epoch 44/50
# 4/4 - 0s - loss: 0.0144 - accuracy: 0.9879 - val_loss: 0.1338 - val_accuracy: 0.8571
# Epoch 45/50
# 4/4 - 0s - loss: 0.0143 - accuracy: 0.9879 - val_loss: 0.1334 - val_accuracy: 0.8571
# Epoch 46/50
# 4/4 - 0s - loss: 0.0146 - accuracy: 0.9879 - val_loss: 0.1379 - val_accuracy: 0.8333
# Epoch 47/50
# 4/4 - 0s - loss: 0.0143 - accuracy: 0.9879 - val_loss: 0.1427 - val_accuracy: 0.8333
# Epoch 48/50
# 4/4 - 0s - loss: 0.0148 - accuracy: 0.9879 - val_loss: 0.1444 - val_accuracy: 0.8095
# Epoch 49/50
# 4/4 - 0s - loss: 0.0149 - accuracy: 0.9879 - val_loss: 0.1414 - val_accuracy: 0.8333
# Epoch 50/50
# 4/4 - 0s - loss: 0.0140 - accuracy: 0.9879 - val_loss: 0.1390 - val_accuracy: 0.8333

# %%
#5. 모델학습과정 표시하고 평가하기
#학습과정 표시하기
fig, loss_ax = plt.subplots()
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'g', label='val loss')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')

acc_ax = loss_ax.twinx() #x축을 공유하는 acc_ax
acc_ax.plot(hist.history['accuracy'], 'b', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'r', label='val accuracy')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')
plt.show()

# %%
#6. 평가 및 예측
score = model.evaluate(X_test, Y_test, verbose=0)
print('model loss:', score[0])
print('model accuracy:', score[1])
# Out:
# model loss: 0.16792500019073486
# model accuracy: 0.8202247023582458

# %%
#7. confusion_matrix(성능 평가지표)
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
pred = model.predict(X_test)
pred = (pred>0.5)
print(confusion_matrix(Y_test, pred), end='\n')
print('f1_score:', f1_score(Y_test, pred))
# Out:
# [[37  5]
#  [11 36]]
# f1_score: 0.8181818181818182
