# %% [markdown]
# **21-03-24 ML_DL 09_DNN 와인감별 (c)cherryuki (ji)**

# %% [markdown]
# # 09. DNN 와인 등급 감별

# %%
import pandas as pd #read_csv, #get_dummies: 원핫인코딩
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.utils as utils #원핫 인코딩
import matplotlib.pyplot as plt

# %%
#1. 데이터셋 생성
raw_data = pd.read_csv('data/winequality-red.csv', sep=';')
raw_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
raw_data.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
raw_data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
Input_data = raw_data.iloc[:, :-1]
Target = raw_data.iloc[:, -1]
print(Target.unique()) #총 6종류(3~8등급)
# Out:
# [5 6 7 4 8 3]

# %% [markdown]
# ### 원 핫 인코딩 방법(2가지)
# 1) utils.to_categorical() <br>
# 2) pd.get_dummies().to_numpy()

# %%
#1. 데이터셋 
raw_data = pd.read_csv('data/winequality-red.csv', sep=';')
raw_data.head()
Input_data = raw_data.iloc[:, :-1]
Target = raw_data.iloc[:, -1]
#scale 조정
scaler = StandardScaler()
scaler.fit(Input_data)
scaled_input = scaler.transform(Input_data)
scaled_input = pd.DataFrame(scaled_input)

#1)one-hot 인코딩:utils.to_categorical()
label_target = utils.to_categorical(Target)

#데이터셋 분할(훈련셋:테스트셋=7:3)
X_train, X_test, Y_train, Y_test = train_test_split(scaled_input, label_target,
                                                   test_size=0.3, random_state=3)
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)

#2. 모델 구성
model = Sequential()
model.add(Dense(units=256, input_dim=11, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=720, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=9, activation='softmax'))

#3. 학습과정 설정
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

#4. 학습 시키기
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(patience=25)
hist = model.fit(X_train, Y_train, epochs=100, batch_size=5,
                validation_split=0.3, verbose=2, callbacks=[early_stopping])

#5. 모델학습과정 표시하고 평가하기
#학습과정 표시하기
fig, loss_ax = plt.subplots()
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'g', label='val loss')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')

acc_ax = loss_ax.twinx() #x축을 공유하는 acc_ax
acc_ax.plot(hist.history['accuracy'], 'b', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'r', label='val accuracy')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')
plt.show()
# Out:
# (1119, 11) (1119, 9) (480, 11) (480, 9)
# Epoch 1/100
# 157/157 - 1s - loss: 0.0719 - accuracy: 0.5083 - val_loss: 0.0625 - val_accuracy: 0.5625
# Epoch 2/100
# 157/157 - 1s - loss: 0.0646 - accuracy: 0.5543 - val_loss: 0.0659 - val_accuracy: 0.5238
# Epoch 3/100
# 157/157 - 1s - loss: 0.0620 - accuracy: 0.5926 - val_loss: 0.0685 - val_accuracy: 0.5060
# Epoch 4/100
# 157/157 - 1s - loss: 0.0627 - accuracy: 0.5875 - val_loss: 0.0610 - val_accuracy: 0.5625
# Epoch 5/100
# 157/157 - 1s - loss: 0.0589 - accuracy: 0.5964 - val_loss: 0.0619 - val_accuracy: 0.5685
# Epoch 6/100
# 157/157 - 1s - loss: 0.0590 - accuracy: 0.5951 - val_loss: 0.0610 - val_accuracy: 0.5714
# Epoch 7/100
# 157/157 - 1s - loss: 0.0588 - accuracy: 0.5939 - val_loss: 0.0605 - val_accuracy: 0.5952
# Epoch 8/100
# 157/157 - 1s - loss: 0.0558 - accuracy: 0.6207 - val_loss: 0.0614 - val_accuracy: 0.5536
# Epoch 9/100
# 157/157 - 1s - loss: 0.0571 - accuracy: 0.6245 - val_loss: 0.0625 - val_accuracy: 0.5893
# Epoch 10/100
# 157/157 - 1s - loss: 0.0565 - accuracy: 0.6130 - val_loss: 0.0631 - val_accuracy: 0.5595
# Epoch 11/100
# 157/157 - 1s - loss: 0.0554 - accuracy: 0.6347 - val_loss: 0.0603 - val_accuracy: 0.6161
# Epoch 12/100
# 157/157 - 1s - loss: 0.0553 - accuracy: 0.6398 - val_loss: 0.0604 - val_accuracy: 0.5744
# Epoch 13/100
# 157/157 - 1s - loss: 0.0545 - accuracy: 0.6322 - val_loss: 0.0632 - val_accuracy: 0.5565
# Epoch 14/100
# 157/157 - 1s - loss: 0.0530 - accuracy: 0.6577 - val_loss: 0.0605 - val_accuracy: 0.5625
# Epoch 15/100
# 157/157 - 1s - loss: 0.0516 - accuracy: 0.6552 - val_loss: 0.0616 - val_accuracy: 0.5476
# Epoch 16/100
# 157/157 - 1s - loss: 0.0507 - accuracy: 0.6743 - val_loss: 0.0639 - val_accuracy: 0.5625
# Epoch 17/100
# 157/157 - 1s - loss: 0.0515 - accuracy: 0.6654 - val_loss: 0.0614 - val_accuracy: 0.5655
# Epoch 18/100
# 157/157 - 1s - loss: 0.0509 - accuracy: 0.6718 - val_loss: 0.0623 - val_accuracy: 0.5565
# Epoch 19/100
# 157/157 - 1s - loss: 0.0504 - accuracy: 0.6782 - val_loss: 0.0646 - val_accuracy: 0.5595
# Epoch 20/100
# 157/157 - 1s - loss: 0.0503 - accuracy: 0.6807 - val_loss: 0.0636 - val_accuracy: 0.5685
# Epoch 21/100
# 157/157 - 1s - loss: 0.0476 - accuracy: 0.6897 - val_loss: 0.0649 - val_accuracy: 0.5714
# Epoch 22/100
# 157/157 - 1s - loss: 0.0492 - accuracy: 0.6986 - val_loss: 0.0640 - val_accuracy: 0.5655
# Epoch 23/100
# 157/157 - 1s - loss: 0.0480 - accuracy: 0.7050 - val_loss: 0.0634 - val_accuracy: 0.5595
# Epoch 24/100
# 157/157 - 1s - loss: 0.0466 - accuracy: 0.7063 - val_loss: 0.0643 - val_accuracy: 0.5714
# Epoch 25/100
# 157/157 - 1s - loss: 0.0458 - accuracy: 0.7126 - val_loss: 0.0630 - val_accuracy: 0.5863
# Epoch 26/100
# 157/157 - 1s - loss: 0.0449 - accuracy: 0.7152 - val_loss: 0.0651 - val_accuracy: 0.5744
# Epoch 27/100
# 157/157 - 1s - loss: 0.0450 - accuracy: 0.7165 - val_loss: 0.0645 - val_accuracy: 0.5714
# Epoch 28/100
# 157/157 - 1s - loss: 0.0457 - accuracy: 0.7126 - val_loss: 0.0619 - val_accuracy: 0.5833
# Epoch 29/100
# 157/157 - 1s - loss: 0.0425 - accuracy: 0.7369 - val_loss: 0.0646 - val_accuracy: 0.5655
# Epoch 30/100
# 157/157 - 1s - loss: 0.0424 - accuracy: 0.7318 - val_loss: 0.0686 - val_accuracy: 0.5625
# Epoch 31/100
# 157/157 - 1s - loss: 0.0436 - accuracy: 0.7114 - val_loss: 0.0620 - val_accuracy: 0.5863
# Epoch 32/100
# 157/157 - 1s - loss: 0.0427 - accuracy: 0.7331 - val_loss: 0.0649 - val_accuracy: 0.5952
# Epoch 33/100
# 157/157 - 1s - loss: 0.0429 - accuracy: 0.7280 - val_loss: 0.0625 - val_accuracy: 0.5952
# Epoch 34/100
# 157/157 - 1s - loss: 0.0416 - accuracy: 0.7382 - val_loss: 0.0637 - val_accuracy: 0.5952
# Epoch 35/100
# 157/157 - 1s - loss: 0.0419 - accuracy: 0.7382 - val_loss: 0.0664 - val_accuracy: 0.5744
# Epoch 36/100
# 157/157 - 1s - loss: 0.0406 - accuracy: 0.7561 - val_loss: 0.0651 - val_accuracy: 0.5774

# %%
#6. 모델 평가
loss_and_matrics = model.evaluate(X_test, Y_test, batch_size=16)
print()
print('loss:', loss_and_matrics[0])
print('accuracy:', loss_and_matrics[1])
# Out:
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 0.6250
#
# loss: 0.06206919252872467
# accuracy: 0.625

# %%
#7. 모델 사용하기
pred = model.predict(X_test).argmax(axis=1)
#pred = np.argmax(model.predict(X_test), axis=1)
real = np.argmax(Y_test, axis=1)
ct = pd.crosstab(pred, real)
ct.index.name='predict'
ct.columns.name='real'
ct
# Out:
# real     3   4    5    6   7  8
# predict
# 4        0   0    1    1   0  0
# 5        3  12  147   52   4  1
# 6        1   3   51  128  30  3
# 7        0   0    3   15  25  0

# %%
#1. 데이터셋 
raw_data = pd.read_csv('data/winequality-red.csv', sep=';')
raw_data.head()
Input_data = raw_data.iloc[:, :-1]
Target = raw_data.iloc[:, -1]
#데이터 전처리; scale 조정, 원 핫 인코딩
scaler = StandardScaler()
scaler.fit(Input_data)
scaled_input = scaler.transform(Input_data)
scaled_input = pd.DataFrame(scaled_input)
#2)one-hot 인코딩: pd.get_dummies()
label_target2 = pd.get_dummies(Target).to_numpy()
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(scaled_input, label_target2,
                                                   test_size=0.3, random_state=5)

#2. 모델 구성
model = Sequential()
model.add(Input(11))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(720, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(6, activation='softmax'))

#3. 학습과정 설정
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

#4. 학습 시키기
early_stopping = EarlyStopping(monitor='val_loss', patience=20)
hist = model.fit(X_train2, Y_train2, epochs=100, batch_size=10,
                validation_split=0.3, verbose=2, callbacks=[early_stopping])

#5. 모델학습과정 표시하고 평가하기
#학습과정 표시하기
fig, loss_ax = plt.subplots()
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'g', label='val loss')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')

acc_ax = loss_ax.twinx() #x축을 공유하는 acc_ax
acc_ax.plot(hist.history['accuracy'], 'b', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'r', label='val accuracy')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')
plt.show()
# Out:
# Epoch 1/100
# 79/79 - 1s - loss: 0.1026 - accuracy: 0.5198 - val_loss: 0.0980 - val_accuracy: 0.5327
# Epoch 2/100
# 79/79 - 0s - loss: 0.0930 - accuracy: 0.5900 - val_loss: 0.0970 - val_accuracy: 0.5536
# Epoch 3/100
# 79/79 - 0s - loss: 0.0894 - accuracy: 0.5913 - val_loss: 0.0937 - val_accuracy: 0.5744
# Epoch 4/100
# 79/79 - 0s - loss: 0.0897 - accuracy: 0.5849 - val_loss: 0.0901 - val_accuracy: 0.5804
# Epoch 5/100
# 79/79 - 0s - loss: 0.0866 - accuracy: 0.5939 - val_loss: 0.0918 - val_accuracy: 0.5804
# Epoch 6/100
# 79/79 - 0s - loss: 0.0852 - accuracy: 0.6232 - val_loss: 0.1043 - val_accuracy: 0.5238
# Epoch 7/100
# 79/79 - 1s - loss: 0.0842 - accuracy: 0.6232 - val_loss: 0.0927 - val_accuracy: 0.5685
# Epoch 8/100
# 79/79 - 0s - loss: 0.0837 - accuracy: 0.6054 - val_loss: 0.0898 - val_accuracy: 0.5804
# Epoch 9/100
# 79/79 - 1s - loss: 0.0826 - accuracy: 0.6245 - val_loss: 0.0940 - val_accuracy: 0.5804
# Epoch 10/100
# 79/79 - 1s - loss: 0.0799 - accuracy: 0.6462 - val_loss: 0.1014 - val_accuracy: 0.5476
# Epoch 11/100
# 79/79 - 0s - loss: 0.0787 - accuracy: 0.6564 - val_loss: 0.0931 - val_accuracy: 0.5923
# Epoch 12/100
# 79/79 - 0s - loss: 0.0786 - accuracy: 0.6526 - val_loss: 0.0912 - val_accuracy: 0.5893
# Epoch 13/100
# 79/79 - 1s - loss: 0.0782 - accuracy: 0.6590 - val_loss: 0.0943 - val_accuracy: 0.5982
# Epoch 14/100
# 79/79 - 0s - loss: 0.0740 - accuracy: 0.6897 - val_loss: 0.0913 - val_accuracy: 0.6161
# Epoch 15/100
# 79/79 - 0s - loss: 0.0749 - accuracy: 0.6782 - val_loss: 0.0887 - val_accuracy: 0.6190
# Epoch 16/100
# 79/79 - 1s - loss: 0.0727 - accuracy: 0.6718 - val_loss: 0.1001 - val_accuracy: 0.5774
# Epoch 17/100
# 79/79 - 1s - loss: 0.0701 - accuracy: 0.6922 - val_loss: 0.0912 - val_accuracy: 0.5952
# Epoch 18/100
# 79/79 - 0s - loss: 0.0709 - accuracy: 0.6897 - val_loss: 0.0902 - val_accuracy: 0.6190
# Epoch 19/100
# 79/79 - 1s - loss: 0.0660 - accuracy: 0.7063 - val_loss: 0.0943 - val_accuracy: 0.6131
# Epoch 20/100
# 79/79 - 0s - loss: 0.0666 - accuracy: 0.7126 - val_loss: 0.0949 - val_accuracy: 0.5744
# Epoch 21/100
# 79/79 - 0s - loss: 0.0658 - accuracy: 0.7229 - val_loss: 0.0932 - val_accuracy: 0.6101
# Epoch 22/100
# 79/79 - 0s - loss: 0.0648 - accuracy: 0.7267 - val_loss: 0.0979 - val_accuracy: 0.6012
# Epoch 23/100
# 79/79 - 1s - loss: 0.0603 - accuracy: 0.7395 - val_loss: 0.0983 - val_accuracy: 0.5893
# Epoch 24/100
# 79/79 - 0s - loss: 0.0628 - accuracy: 0.7369 - val_loss: 0.1024 - val_accuracy: 0.5565
# Epoch 25/100
# 79/79 - 0s - loss: 0.0590 - accuracy: 0.7586 - val_loss: 0.0994 - val_accuracy: 0.5893
# Epoch 26/100
# 79/79 - 1s - loss: 0.0599 - accuracy: 0.7446 - val_loss: 0.1022 - val_accuracy: 0.6101
# Epoch 27/100
# 79/79 - 0s - loss: 0.0566 - accuracy: 0.7637 - val_loss: 0.1034 - val_accuracy: 0.5863
# Epoch 28/100
# 79/79 - 0s - loss: 0.0547 - accuracy: 0.7676 - val_loss: 0.1026 - val_accuracy: 0.5863
# Epoch 29/100
# 79/79 - 0s - loss: 0.0556 - accuracy: 0.7497 - val_loss: 0.0991 - val_accuracy: 0.6101
# Epoch 30/100
# 79/79 - 0s - loss: 0.0550 - accuracy: 0.7701 - val_loss: 0.0953 - val_accuracy: 0.5923
# Epoch 31/100
# 79/79 - 1s - loss: 0.0507 - accuracy: 0.7854 - val_loss: 0.1003 - val_accuracy: 0.5833
# Epoch 32/100
# 79/79 - 1s - loss: 0.0482 - accuracy: 0.8084 - val_loss: 0.0958 - val_accuracy: 0.6429
# Epoch 33/100
# 79/79 - 0s - loss: 0.0517 - accuracy: 0.7842 - val_loss: 0.0981 - val_accuracy: 0.6250
# Epoch 34/100
# 79/79 - 0s - loss: 0.0518 - accuracy: 0.7931 - val_loss: 0.0978 - val_accuracy: 0.6339
# Epoch 35/100
# 79/79 - 0s - loss: 0.0486 - accuracy: 0.8059 - val_loss: 0.0985 - val_accuracy: 0.6101

# %%
#6. 모델 평가
loss_and_matrics = model.evaluate(X_test2, Y_test2, batch_size=16)
print()
print('loss:', loss_and_matrics[0])
print('accuracy:', loss_and_matrics[1])
# Out:
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0966 - accuracy: 0.6125
#
# loss: 0.096592478454113
# accuracy: 0.612500011920929

# %%
#7. 모델 사용하기
pred = model.predict(X_test2).argmax(axis=1)+3
#model.predict_classes(X_test2)+3
real = np.argmax(Y_test2, axis=1)+3

# %%
ct = pd.crosstab(pred, real)
ct.index.name='predict'
ct.columns.name='real'
ct
# Out:
# real     3  4    5   6   7  8
# predict
# 3        0  0    0   1   0  0
# 4        1  1    4   2   0  0
# 5        2  4  158  53   3  0
# 6        0  5   47  98  25  4
# 7        0  1    4  27  37  3
