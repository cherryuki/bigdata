# %% [markdown]
# **21-03-12 python 13_데이터 시각화(seaborn) (c)cherryuki (ji)**

# %% [markdown]
# # ch13_데이터 시각화_빅데이터 처리 시스템 포트폴리오
# ## 예제1) 전국 신규 민간 아파트 분양가격 동향

# %% [markdown]
# ### 1. 시작 전 설정

# %%
#새 파일 시작전 설정
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineVackend.figure_format = 'retina'
#한글 설정
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) #y축
#경고 메시지 안보이게
import warnings
warnings.filterwarnings(action='ignore')
# warnings.filterwarnings(action='default') #경고 메시지 보이게

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 2. https://www.data.go.kr “주택도시보증공사_전국 신규 민간아파트 분양가격 동향”
# - ① 2013년9월부터 2015년8월까지 데이터는 df_first 변수에 담아 탐색
# - ② 이후 데이터는 df_last 변수에 담아 탐색

# %%
df_first = pd.read_csv('data/전국 평균 평당 분양가격(2013년 9월부터 2015년 8월까지).csv', encoding='cp949')
df_last = pd.read_csv('data/주택도시보증공사_전국 신규 민간아파트 분양가격 동향_20210215.csv', encoding='CP949')

# %%
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
# 3     9974     9973  ...     10020     10020    10017     9876     9876
# 4     7612     7622  ...      7752      7748     7752     7756     7861
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
# 2     8446     8568     8542     8542     8795
# 3     9938    10551    10443    10443    10449
# 4     7914     7877     7881     8089     8231
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 3. df_last의 데이터 결측치를 확인하고 대체할지 고민

# %%
df_last.isnull().sum() #분양가격에만 결측치
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    430
# dtype: int64

# %%
df_last.info() #5440 데이터
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      5440 non-null   object
#  1   규모구분     5440 non-null   object
#  2   연도       5440 non-null   int64
#  3   월        5440 non-null   int64
#  4   분양가격(㎡)  5010 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 212.6+ KB

# %% [markdown]
# ### 4. df_last 데이터셋에 평당분양가격 칼럼 추가

# %%
df_last['분양가격(㎡)'] = pd.to_numeric(df_last['분양가격(㎡)'], errors='coerce')
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      5440 non-null   object
#  1   규모구분     5440 non-null   object
#  2   연도       5440 non-null   int64
#  3   월        5440 non-null   int64
#  4   분양가격(㎡)  4918 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 212.6+ KB

# %%
df_last['평당분양가격'] = df_last['분양가격(㎡)']*3.3
df_last.head()
# Out:
#   지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 0  서울               모든면적  2015  10   5841.0  19275.3
# 1  서울         전용면적 60㎡이하  2015  10   5652.0  18651.6
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10   5882.0  19410.6
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10   5721.0  18879.3
# 4  서울        전용면적 102㎡초과  2015  10   5879.0  19400.7

# %% [markdown]
# ### 4-2. 분양가격 , 있는 것도 바꿔서 처리

# %%
df_last = pd.read_csv('data/주택도시보증공사_전국 신규 민간아파트 분양가격 동향_20210215.csv', encoding='CP949')

# %%
type(df_last.loc[0, "분양가격(㎡)"])
# Out:
# str

# %%
#공백인 부분 결측치 처리하기
df_last[df_last["분양가격(㎡)"]=="  "]
# Out:
#     지역명               규모구분    연도   월 분양가격(㎡)
# 28   광주  전용면적 85㎡초과 102㎡이하  2015  10
# 29   광주        전용면적 102㎡초과  2015  10
# 34   대전        전용면적 102㎡초과  2015  10
# 81   제주         전용면적 60㎡이하  2015  10
# 113  광주  전용면적 85㎡초과 102㎡이하  2015  11
# 114  광주        전용면적 102㎡초과  2015  11
# 119  대전        전용면적 102㎡초과  2015  11
# 166  제주         전용면적 60㎡이하  2015  11
# 198  광주  전용면적 85㎡초과 102㎡이하  2015  12
# 199  광주        전용면적 102㎡초과  2015  12
# 204  대전        전용면적 102㎡초과  2015  12
# 251  제주         전용면적 60㎡이하  2015  12
# 283  광주  전용면적 85㎡초과 102㎡이하  2016   1
# 284  광주        전용면적 102㎡초과  2016   1
# 289  대전        전용면적 102㎡초과  2016   1
# 336  제주         전용면적 60㎡이하  2016   1

# %%
df_last[df_last["분양가격(㎡)"]=="  "]["분양가격(㎡)"].index
row = [28, 29, 34, 81, 113, 114, 119, 166, 198, 199, 204, 251, 283, 284, 289, 336]
for r in row:
    df_last.loc[r, '분양가격(㎡)'] = np.nan #결측치 넣기

# %%
df_last[df_last["분양가격(㎡)"]=="  "]["분양가격(㎡)"]
# Out:
# Series([], Name: 분양가격(㎡), dtype: object)

# %%
df_last.loc[df_last["분양가격(㎡)"].notnull() & (df_last["분양가격(㎡)"].str.find(",")!=-1)]
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 2125  서울               모든면적  2017  11   6,657
# 2126  서울         전용면적 60㎡이하  2017  11   6,931
# 2127  서울   전용면적 60㎡초과 85㎡이하  2017  11   5,899
# 2128  서울  전용면적 85㎡초과 102㎡이하  2017  11   7,311
# 2129  서울        전용면적 102㎡초과  2017  11   6,880
# ...   ..                ...   ...  ..     ...
# 2203  경남  전용면적 85㎡초과 102㎡이하  2017  11   2,914
# 2204  경남        전용면적 102㎡초과  2017  11   2,838
# 2205  제주               모든면적  2017  11   3,560
# 2206  제주         전용면적 60㎡이하  2017  11   5,380
# 2207  제주   전용면적 60㎡초과 85㎡이하  2017  11   3,477
#
# [76 rows x 5 columns]

# %%
#,를 제거하고 숫자로 바꾸기
df_last['분양가격(㎡)'] = df_last['분양가격(㎡)'].str.replace(',', '')

# %%
df_last.iloc[2125:2129, :]
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 2125  서울               모든면적  2017  11    6657
# 2126  서울         전용면적 60㎡이하  2017  11    6931
# 2127  서울   전용면적 60㎡초과 85㎡이하  2017  11    5899
# 2128  서울  전용면적 85㎡초과 102㎡이하  2017  11    7311

# %%
type(df_last.loc[2125,'분양가격(㎡)'])
# Out:
# str

# %%
df_last.isnull().sum() #공백 부분 결측치 처리하여 결측치 개수 늘어남
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    446
# dtype: int64

# %%
df_last['분양가격(㎡)'].describe() #문자형기술통계 요약정보
# Out:
# count     4994
# unique    2018
# top       3395
# freq        18
# Name: 분양가격(㎡), dtype: object

# %%
#df_last['분양가격(㎡)'] = pd.to_numeric(df_last['분양가격(㎡)'], errors='coerce')
df_last['분양가격(㎡)'] = df_last['분양가격(㎡)'].astype('float64')

# %%
df_last['분양가격(㎡)'].describe() #숫자형 기술통계 요약정보
# Out:
# count     4994.000000
# mean      3375.965759
# std       1368.671841
# min       1868.000000
# 25%       2510.000000
# 50%       2990.000000
# 75%       3816.250000
# max      13835.000000
# Name: 분양가격(㎡), dtype: float64

# %%
df_last.info() #분양가격 개수 4918 -> 4994로 증가(76개)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      5440 non-null   object
#  1   규모구분     5440 non-null   object
#  2   연도       5440 non-null   int64
#  3   월        5440 non-null   int64
#  4   분양가격(㎡)  4994 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 212.6+ KB

# %%
df_last['평당분양가격'] = df_last['분양가격(㎡)']*3.3
df_last.head()
# Out:
#   지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 0  서울               모든면적  2015  10   5841.0  19275.3
# 1  서울         전용면적 60㎡이하  2015  10   5652.0  18651.6
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10   5882.0  19410.6
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10   5721.0  18879.3
# 4  서울        전용면적 102㎡초과  2015  10   5879.0  19400.7

# %% [markdown]
# ### 5. df_last 데이터셋에서 전용면적 컬럼을 추가한다(아래와 같이 규모구분 컬럼을 이용)

# %%
df_last['전용면적'] = df_last['규모구분'].apply(lambda x:x.replace('전용면적', '').strip().replace(' ',''))
df_last['전용면적'] = df_last['전용면적'].apply(lambda x:x.replace('초과','~').replace('이하',''))
df_last['전용면적'] = df_last['전용면적'].apply(lambda x:x.replace('모든면적','전체'))
df_last.head()
# Out:
#   지역명          규모구분    연도   월  분양가격(㎡)   평당분양가격      전용면적
# 0  서울            전체  2015  10   5841.0  19275.3        전체
# 1  서울       전용면적60㎡  2015  10   5652.0  18651.6       60㎡
# 2  서울   전용면적60㎡~85㎡  2015  10   5882.0  19410.6   60㎡~85㎡
# 3  서울  전용면적85㎡~102㎡  2015  10   5721.0  18879.3  85㎡~102㎡
# 4  서울     전용면적102㎡~  2015  10   5879.0  19400.7     102㎡~

# %%
#apply대신 str.replace 이용도 동일
df_last['전용면적'] = df_last['규모구분'].str.replace("전용면적", "")
df_last['전용면적'] = df_last['전용면적'].str.replace('초과','~').str.replace('이하','')
df_last['전용면적'] = df_last['전용면적'].str.replace('모든면적','전체').str.replace(' ','')
df_last.head()
# Out:
#   지역명          규모구분    연도   월  분양가격(㎡)   평당분양가격      전용면적
# 0  서울            전체  2015  10   5841.0  19275.3        전체
# 1  서울       전용면적60㎡  2015  10   5652.0  18651.6       60㎡
# 2  서울   전용면적60㎡~85㎡  2015  10   5882.0  19410.6   60㎡~85㎡
# 3  서울  전용면적85㎡~102㎡  2015  10   5721.0  18879.3  85㎡~102㎡
# 4  서울     전용면적102㎡~  2015  10   5879.0  19400.7     102㎡~

# %% [markdown]
# ### 6. 메모리 사용량을 줄이기 위해 사용하지 않을 컬럼은 제거한 후(df_last.drop([‘규모구분’,’분양가격((㎡)’], axis=1 이용), 메모리 사용량을 전후로 확인

# %%
df_last.info() #memory usage: 297.6+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      5440 non-null   object
#  1   규모구분     5440 non-null   object
#  2   연도       5440 non-null   int64
#  3   월        5440 non-null   int64
#  4   분양가격(㎡)  4994 non-null   float64
#  5   평당분양가격   4994 non-null   float64
#  6   전용면적     5440 non-null   object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 297.6+ KB

# %%
df_last = df_last.drop(['규모구분', '분양가격(㎡)'], axis=1)
df_last.info() #memory usage: 212.6+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     5440 non-null   object
#  1   연도      5440 non-null   int64
#  2   월       5440 non-null   int64
#  3   평당분양가격  4994 non-null   float64
#  4   전용면적    5440 non-null   object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 212.6+ KB

# %% [markdown]
# ### 7. GroupBy(unstack()함수 이용) vs. pivot_table
# - 지역별 데이터 수
# - 지역별 평당분양가격(평균)
# - 전용면적별 평당분양가격(평균)
# - 지역별, 전용면적별 평당분양가격(평균)
# - 연도, 지역별 평당분양가격(평균) - 힌트:unstack()

# %%
#지역별 데이터 수1 - groupby
df_last.groupby(df_last['지역명']).count()
# Out:
#       연도    월  평당분양가격  전용면적
# 지역명
# 강원   320  320     308   320
# 경기   320  320     320   320
# 경남   320  320     311   320
# 경북   320  320     298   320
# 광주   320  320     266   320
# 대구   320  320     311   320
# 대전   320  320     243   320
# 부산   320  320     320   320
# 서울   320  320     320   320
# 세종   320  320     265   320
# 울산   320  320     201   320
# 인천   320  320     316   320
# 전남   320  320     314   320
# 전북   320  320     317   320
# 제주   320  320     264   320
# 충남   320  320     302   320
# 충북   320  320     318   320

# %%
#지역별 데이터 수2 - pivot_table
df_last.pivot_table(index='지역명', aggfunc='count')
# Out:
#       연도    월  전용면적  평당분양가격
# 지역명
# 강원   320  320   320     308
# 경기   320  320   320     320
# 경남   320  320   320     311
# 경북   320  320   320     298
# 광주   320  320   320     266
# 대구   320  320   320     311
# 대전   320  320   320     243
# 부산   320  320   320     320
# 서울   320  320   320     320
# 세종   320  320   320     265
# 울산   320  320   320     201
# 인천   320  320   320     316
# 전남   320  320   320     314
# 전북   320  320   320     317
# 제주   320  320   320     264
# 충남   320  320   320     302
# 충북   320  320   320     318

# %%
#지역별 평당분양가격(평균)1 - groupby
df_last.groupby(['지역명'])['평당분양가격'].mean().to_frame()
# Out:
#            평당분양가격
# 지역명
# 강원    8381.260714
# 경기   13689.699375
# 경남    9580.547267
# 경북    8686.530201
# 광주   10736.649248
# 대구   12683.152090
# 대전   10394.551852
# 부산   12353.776875
# 서울   24826.590937
# 세종    9959.549434
# 울산   10726.494030
# 인천   12557.617405
# 전남    7959.799682
# 전북    7891.059937
# 제주   11765.637500
# 충남    8403.264238
# 충북    7780.030189

# %%
#지역별 평당분양가격(평균)2 - pivot_table
pd.pivot_table(df_last, index='지역명', values='평당분양가격')
# Out:
#            평당분양가격
# 지역명
# 강원    8381.260714
# 경기   13689.699375
# 경남    9580.547267
# 경북    8686.530201
# 광주   10736.649248
# 대구   12683.152090
# 대전   10394.551852
# 부산   12353.776875
# 서울   24826.590937
# 세종    9959.549434
# 울산   10726.494030
# 인천   12557.617405
# 전남    7959.799682
# 전북    7891.059937
# 제주   11765.637500
# 충남    8403.264238
# 충북    7780.030189

# %%
#전용면적별 평당분양가격(평균)1 - groupby
t = df_last.groupby(['전용면적'])['평당분양가격'].mean().to_frame()
t = t.loc[['60㎡','60㎡~85㎡','85㎡~102㎡','102㎡~','전체'],:]
t
# Out:
#                 평당분양가격
# 전용면적
# 60㎡       10798.312020
# 60㎡~85㎡   10684.018318
# 85㎡~102㎡  11725.869017
# 102㎡~     11973.137487
# 전체        10694.884809

# %%
#전용면적별 평당분양가격(평균)2 - pivot_table
t = df_last.pivot_table(index='전용면적', values='평당분양가격')
t = t.loc[['60㎡','60㎡~85㎡','85㎡~102㎡','102㎡~','전체'],:]
t
# Out:
#                 평당분양가격
# 전용면적
# 60㎡       10798.312020
# 60㎡~85㎡   10684.018318
# 85㎡~102㎡  11725.869017
# 102㎡~     11973.137487
# 전체        10694.884809

# %%
#지역별, 전용면적별 평당분양가격(평균)1 - groupby
t = df_last.groupby(['지역명','전용면적'])['평당분양가격'].mean().unstack()
t = t.loc[:,['전체','60㎡','60㎡~85㎡','85㎡~102㎡','102㎡~']]
t
# Out:
# 전용면적            전체           60㎡       60㎡~85㎡      85㎡~102㎡         102㎡~
# 지역명
# 강원     7872.820313   8044.110937   7850.854688   8866.465385   9363.028125
# 경기    12917.695313  13489.884375  12877.218750  14154.885937  15008.812500
# 경남     8958.932812   8876.095161   8923.509375  10892.990625  10308.852632
# 경북     8385.918750   8368.851562   8368.903125   9093.113333   9368.537705
# 광주    10431.918750  10157.511864  10440.632812  11197.960714  11907.241176
# 대구    12464.564062  12559.232812  12469.101562  12120.060000  13723.617187
# 대전    10034.217188   9549.460345   9976.106250   9077.566667  14875.080000
# 부산    12225.365625  11713.556250  12173.545313  12376.598437  13279.818750
# 서울    23494.917188  24131.404688  23548.026563  28228.715625  24729.890625
# 세종    10000.763793   9421.246154   9895.440000   9975.600000  10325.870690
# 울산    10937.400000  10282.646512  10983.780000   8861.007692  11228.957143
# 인천    11959.870312  11873.760938  12061.964063  12275.432813  14754.355000
# 전남     7589.896875   7497.120968   7570.870312   8276.400000   8870.039063
# 전북     7506.314063   7773.975000   7487.339063   8394.172131   8317.082812
# 제주    11603.831250  14126.157692  11478.018750  10709.082353  10604.418000
# 충남     8025.032812   7998.993750   8046.482812   9405.435849   8750.615789
# 충북     7372.612500   7293.773438   7407.778125   8465.830645   8381.587500

# %%
#지역별, 전용면적별 평당분양가격(평균)2 - pivot_table
t = df_last.pivot_table(index=['지역명','전용면적'],values='평당분양가격').unstack()
t.columns = t.columns.droplevel(level=0)
t = t.loc[:,['전체','60㎡','60㎡~85㎡','85㎡~102㎡','102㎡~']]
t
# Out:
# 전용면적            전체           60㎡       60㎡~85㎡      85㎡~102㎡         102㎡~
# 지역명
# 강원     7872.820313   8044.110937   7850.854688   8866.465385   9363.028125
# 경기    12917.695313  13489.884375  12877.218750  14154.885937  15008.812500
# 경남     8958.932812   8876.095161   8923.509375  10892.990625  10308.852632
# 경북     8385.918750   8368.851562   8368.903125   9093.113333   9368.537705
# 광주    10431.918750  10157.511864  10440.632812  11197.960714  11907.241176
# 대구    12464.564062  12559.232812  12469.101562  12120.060000  13723.617187
# 대전    10034.217188   9549.460345   9976.106250   9077.566667  14875.080000
# 부산    12225.365625  11713.556250  12173.545313  12376.598437  13279.818750
# 서울    23494.917188  24131.404688  23548.026563  28228.715625  24729.890625
# 세종    10000.763793   9421.246154   9895.440000   9975.600000  10325.870690
# 울산    10937.400000  10282.646512  10983.780000   8861.007692  11228.957143
# 인천    11959.870312  11873.760938  12061.964063  12275.432813  14754.355000
# 전남     7589.896875   7497.120968   7570.870312   8276.400000   8870.039063
# 전북     7506.314063   7773.975000   7487.339063   8394.172131   8317.082812
# 제주    11603.831250  14126.157692  11478.018750  10709.082353  10604.418000
# 충남     8025.032812   7998.993750   8046.482812   9405.435849   8750.615789
# 충북     7372.612500   7293.773438   7407.778125   8465.830645   8381.587500

# %%
#연도, 지역별 평당분양가격(평균) - 힌트:unstack()1- groupby
t = df_last.groupby(['지역명', '연도'])['평당분양가격'].mean().unstack()
t
# Out:
# 연도        2015          2016          2017          2018          2019  \
# 지역명
# 강원    7188.060   7162.903846   7318.850000   8219.255000   8934.475000
# 경기   11060.940  11684.970000  12296.185000  14258.420000  15665.540000
# 경남    8459.220   8496.730000   8806.600000   9327.670000  10697.615789
# 경북    7464.160   7753.405000   8288.063793   8680.776923   9050.250000
# 광주    7916.700   9190.683333   9599.700000   9526.953333  12111.675000
# 대구    9018.900  10282.030000  12191.972222  12139.252632  14081.650000
# 대전    8190.600   8910.733333   9912.910526  10234.106667  12619.200000
# 부산   10377.400  10743.535000  11637.615000  12889.965000  13537.865000
# 서울   20315.680  21753.435000  21864.095000  23202.245000  28286.830000
# 세종    8765.020   8857.805000   9132.945763  10340.463158  11299.394118
# 울산    9367.600   9582.574138  10630.160870  10241.400000  10216.250000
# 인천   10976.020  11099.055000  11672.430000  11881.532143  13249.775000
# 전남    6798.880   6936.600000   7413.230000   7929.845000   8219.275862
# 전북    7110.400   6906.625000   7406.126316   8174.595000   8532.260000
# 제주    7951.075   9567.480000  12628.539623  11935.968000  11828.469231
# 충남    7689.880   7958.225000   8157.315517   8201.820000   8748.840000
# 충북    6828.800   7133.335000   7462.565000   8149.295000   7970.875000
#
# 연도           2020      2021
# 지역명
# 강원   10302.423214  11169.18
# 경기   15106.080000  14823.60
# 경남   10919.272222  11079.42
# 경북    9997.693750  11281.38
# 광주   13406.485714  13445.52
# 대구   15314.200000  15640.02
# 대전   11238.844737  10444.50
# 부산   13353.010000  13565.64
# 서울   29781.015000  29303.34
# 세종   11628.100000  12502.38
# 울산   12837.600000  14493.60
# 인천   14982.990000  15589.20
# 전남    9562.398214   9680.22
# 전북    8559.430000   8457.24
# 제주   14192.876923  16596.80
# 충남    9139.380000   9216.90
# 충북    8358.956897   8766.78

# %%
#5) 연도, 지역별 평당분양가격(평균) - 힌트: unstack()2 - pivot_table
t = df_last.pivot_table(index=['연도', '지역명'], values='평당분양가격').unstack().T
t.index = t.index.droplevel(level=0)
t
# Out:
# 연도        2015          2016          2017          2018          2019  \
# 지역명
# 강원    7188.060   7162.903846   7318.850000   8219.255000   8934.475000
# 경기   11060.940  11684.970000  12296.185000  14258.420000  15665.540000
# 경남    8459.220   8496.730000   8806.600000   9327.670000  10697.615789
# 경북    7464.160   7753.405000   8288.063793   8680.776923   9050.250000
# 광주    7916.700   9190.683333   9599.700000   9526.953333  12111.675000
# 대구    9018.900  10282.030000  12191.972222  12139.252632  14081.650000
# 대전    8190.600   8910.733333   9912.910526  10234.106667  12619.200000
# 부산   10377.400  10743.535000  11637.615000  12889.965000  13537.865000
# 서울   20315.680  21753.435000  21864.095000  23202.245000  28286.830000
# 세종    8765.020   8857.805000   9132.945763  10340.463158  11299.394118
# 울산    9367.600   9582.574138  10630.160870  10241.400000  10216.250000
# 인천   10976.020  11099.055000  11672.430000  11881.532143  13249.775000
# 전남    6798.880   6936.600000   7413.230000   7929.845000   8219.275862
# 전북    7110.400   6906.625000   7406.126316   8174.595000   8532.260000
# 제주    7951.075   9567.480000  12628.539623  11935.968000  11828.469231
# 충남    7689.880   7958.225000   8157.315517   8201.820000   8748.840000
# 충북    6828.800   7133.335000   7462.565000   8149.295000   7970.875000
#
# 연도           2020      2021
# 지역명
# 강원   10302.423214  11169.18
# 경기   15106.080000  14823.60
# 경남   10919.272222  11079.42
# 경북    9997.693750  11281.38
# 광주   13406.485714  13445.52
# 대구   15314.200000  15640.02
# 대전   11238.844737  10444.50
# 부산   13353.010000  13565.64
# 서울   29781.015000  29303.34
# 세종   11628.100000  12502.38
# 울산   12837.600000  14493.60
# 인천   14982.990000  15589.20
# 전남    9562.398214   9680.22
# 전북    8559.430000   8457.24
# 제주   14192.876923  16596.80
# 충남    9139.380000   9216.90
# 충북    8358.956897   8766.78

# %%
plt.figure(figsize=(15,6))
sns.heatmap(t, annot=True, fmt='.0f', cmap='Blues', annot_kws={'size':12})
plt.show()

# %% [markdown]
# ### 8. 위의 그룹화한 내용을 선그래프와 막대그래프로 시각화

# %%
t2 = df_last.groupby(['지역명'])['평당분양가격'].mean()
t2.plot()
plt.show()

# %%
t2 = pd.pivot_table(df_last, index='지역명', values='평당분양가격').sort_values(by='평당분양가격', ascending=False)
t2.plot(kind='bar', figsize=(10,4), legend=None, 
        title="지역별 평당분양가격(평균)", ylabel="평당분양가격",rot=0)
plt.show()

# %%
t2.plot(legend=None)
plt.show()

# %%
t = df_last.groupby(['지역명', '연도'])['평당분양가격'].mean().unstack()
t.plot(figsize=(10,5), title="연도별 지역별 평당분양가격(평균)", ylabel="평당분양가격")
plt.savefig('data/ch13_example1-1.png')

# %%
a = df_last.groupby(['전용면적'])['평당분양가격'].mean().to_frame()
a = a.loc[['60㎡','60㎡~85㎡','85㎡~102㎡','102㎡~','전체'],:]
a.plot(kind='bar', legend=None, rot=0)
plt.show()

# %%
price_per_year=df_last.groupby(df_last['연도'])['평당분양가격'].mean()
price_per_year.plot(legend=None, ylabel="평당분양가격(평균)")
plt.show()

# %%
b = df_last.groupby(['지역명','전용면적'])['평당분양가격'].mean().unstack()
b = b.loc[:,['전체','60㎡','60㎡~85㎡','85㎡~102㎡','102㎡~']]
b.boxplot()
# Out:
# <AxesSubplot:>

# %%
c = df_last.groupby(['연도','전용면적'])['평당분양가격'].mean().unstack().T
c = c.loc[['60㎡', '60㎡~85㎡', '85㎡~102㎡', '102㎡~', '전체'],:]
c.boxplot(grid=False)
plt.show()

# %%
d = df_last.pivot_table(index='월', columns='연도', values='평당분양가격')
d.boxplot(grid=False)
plt.show()

# %%
d = df_last.pivot_table(index='월', columns='연도', values='평당분양가격')
d.plot.box()
plt.show()

# %%
#연도별 월별 평당분양가격의 추이
d.plot()
plt.legend(bbox_to_anchor=(1.01, 1), loc=0, borderaxespad=0.)
plt.show()

# %% [markdown]
# ### 9. seaborn으로 시각화(위에서 그린 시각화내용을 일부또는 그 이상을 seaborn으로 시각화
# 1) 지역별 평당분양가격(평균)

# %%
import seaborn as sns
plt.figure(figsize=(10,3))
sns.barplot(x='지역명', y='평당분양가격', data=df_last, ci=None).set_title("지역별 평당분양가격(평균)")
plt.savefig('data/ch13_example1-2.png')

# %%
m = df_last.groupby(["지역명"])["평당분양가격"].mean().sort_values().to_frame()
plt.figure(figsize=(10,3))
sns.barplot(data=m, x=m.index, y='평당분양가격', palette='Blues')
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
sns.barplot(x='연도', y='평당분양가격', data=df_last).set_title("연도별 평당분양가격(평균)")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.barplot(x='지역명', y='평당분양가격', data=df_last, ci=None, hue='연도').set_title("지역별 연도별 평당분양가격(평균)")
plt.legend(bbox_to_anchor=(1.01,1), loc=2, borderaxespad=0.)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_last, x='연도', y='평당분양가격', hue='지역명', palette='Accent')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(10,5))
sns.relplot(data=df_last, x='연도', y='평당분양가격', hue='지역명', 
            kind='line', col='지역명', col_wrap=4)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df_last, x='연도', y='평당분양가격', palette='Set3')
plt.savefig('data/ch13_example1-3.png')

# %%
sns.boxenplot(x='연도', y='평당분양가격', data=df_last, palette='Set3')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxenplot(x='지역명', y='평당분양가격', data=df_last, palette='Set2')
plt.show()

# %%
sns.boxenplot(x='전용면적', y='평당분양가격', data=df_last)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=df_last, x='연도', y='평당분양가격', hue='전용면적', palette='Set3')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.violinplot(x='연도', y='평당분양가격', data=df_last, palette='Set3')
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
plt.figure(figsize=(12,4))
sns.violinplot(x='지역명', y='평당분양가격', data=df_last, palette='Set3')
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
plt.figure(figsize=(12,4))
sns.violinplot(x='전용면적', y='평당분양가격', data=df_last, palette='Set3')
# Out:
# <AxesSubplot:xlabel='전용면적', ylabel='평당분양가격'>

# %%
sns.stripplot(x='전용면적', y='평당분양가격', data=df_last, palette='Spectral')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.swarmplot(x='전용면적', y='평당분양가격', data=df_last, palette='YlGnBu').set_title("전용면적별 평당분양가격(평균)")
plt.savefig('data/ch13_example1-4.png')

# %%
plt.figure(figsize=(12,4))
sns.swarmplot(x='연도', y='평당분양가격', data=df_last, palette='Spectral')
plt.show()

# %%
#상기 그래프를 통해 이상치로 추정되는 내용 표로 확인
max_price = df_last[df_last['평당분양가격']>40000]
max_price
# Out:
#      지역명    연도   월   평당분양가격      전용면적
# 3743  서울  2019   6  42002.4  85㎡~102㎡
# 3828  서울  2019   7  42002.4  85㎡~102㎡
# 3913  서울  2019   8  42002.4  85㎡~102㎡
# 3998  서울  2019   9  42002.4  85㎡~102㎡
# 4083  서울  2019  10  42002.4  85㎡~102㎡
# 4168  서울  2019  11  42002.4  85㎡~102㎡
# 4253  서울  2019  12  42002.4  85㎡~102㎡
# 4338  서울  2020   1  42002.4  85㎡~102㎡
# 4423  서울  2020   2  45655.5  85㎡~102㎡
# 4508  서울  2020   3  45655.5  85㎡~102㎡
# 4593  서울  2020   4  45655.5  85㎡~102㎡
# 4763  서울  2020   6  41537.1  85㎡~102㎡

# %%
df_last['평당분양가격'].hist()
plt.show()

# %%
sns.displot(df_last['평당분양가격'], kde=True)
plt.show()

# %% [markdown]
# ### 10. 구조가 다른 df_first와 df_last의 전용면적 전체의 데이터를 하나의 같은 데이터 셋으로 합쳐서 분석

# %%
df_last.sample()
# Out:
#      지역명    연도  월   평당분양가격     전용면적
# 3997  서울  2019  9  28287.6  60㎡~85㎡

# %%
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
# 3     9974     9973  ...     10020     10020    10017     9876     9876
# 4     7612     7622  ...      7752      7748     7752     7756     7861
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
# 2     8446     8568     8542     8542     8795
# 3     9938    10551    10443    10443    10449
# 4     7914     7877     7881     8089     8231
#
# [5 rows x 22 columns]

# %%
new_df_first = df_first.melt(id_vars='지역', var_name='연도월', value_name='평당분양가격')
new_df_first.head()
# Out:
#    지역       연도월  평당분양가격
# 0  서울  2013년12월   18189
# 1  부산  2013년12월    8111
# 2  대구  2013년12월    8080
# 3  인천  2013년12월   10204
# 4  광주  2013년12월    6098

# %%
new_df_first["연도"] = new_df_first["연도월"].apply(lambda x:int(x.split("년")[0]))
new_df_first["월"] = new_df_first["연도월"].apply(lambda x:int(x.split("년")[1].replace("월","")))
new_df_first.head()
# Out:
#    지역       연도월  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12
# 1  부산  2013년12월    8111  2013  12
# 2  대구  2013년12월    8080  2013  12
# 3  인천  2013년12월   10204  2013  12
# 4  광주  2013년12월    6098  2013  12

# %%
new_df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      357 non-null    object
#  1   연도월     357 non-null    object
#  2   평당분양가격  357 non-null    int64
#  3   연도      357 non-null    int64
#  4   월       357 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 14.1+ KB

# %%
new_first = new_df_first.drop('연도월', axis=1)
new_first.head()
# Out:
#    지역  평당분양가격    연도   월
# 0  서울   18189  2013  12
# 1  부산    8111  2013  12
# 2  대구    8080  2013  12
# 3  인천   10204  2013  12
# 4  광주    6098  2013  12

# %%
new_first.columns=['지역명', '평당분양가격','연도','월']
new_first.head()
# Out:
#   지역명  평당분양가격    연도   월
# 0  서울   18189  2013  12
# 1  부산    8111  2013  12
# 2  대구    8080  2013  12
# 3  인천   10204  2013  12
# 4  광주    6098  2013  12

# %%
new_last = df_last[df_last['전용면적']=='전체']
new_last.drop('전용면적', axis=1, inplace=True)
new_last.head()
# Out:
#    지역명    연도   월   평당분양가격
# 0   서울  2015  10  19275.3
# 5   인천  2015  10  10437.9
# 10  경기  2015  10  10355.4
# 15  부산  2015  10  10269.6
# 20  대구  2015  10   8850.6

# %%
result=pd.concat([new_first, new_last])
result.head()
# Out:
#   지역명   평당분양가격    연도   월
# 0  서울  18189.0  2013  12
# 1  부산   8111.0  2013  12
# 2  대구   8080.0  2013  12
# 3  인천  10204.0  2013  12
# 4  광주   6098.0  2013  12

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1445 entries, 0 to 5435
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     1445 non-null   object
#  1   평당분양가격  1430 non-null   float64
#  2   연도      1445 non-null   int64
#  3   월       1445 non-null   int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 56.4+ KB

# %%
result.pivot_table(index='연도', values='평당분양가격', columns='지역명').T
# Out:
# 연도      2013          2014          2015       2016       2017       2018  \
# 지역명
# 강원    6230.0   6332.500000   6831.154545   7011.125   7170.625   7680.750
# 경기   10855.0  10509.083333  10489.109091  11220.000  11840.675  13185.975
# 경남    6473.0   6728.750000   7646.163636   7847.950   8163.925   9019.450
# 경북    6168.0   6536.500000   7035.063636   7360.650   7802.575   8505.200
# 광주    6098.0   7587.833333   7956.090909   8898.725   9471.000   9855.725
# 대구    8080.0   8286.083333   8706.718182  10310.025  11507.100  12075.800
# 대전    8321.0   8240.333333   8104.509091   8501.625   9056.025  10180.225
# 부산    8111.0   9180.166667   9633.272727  10429.925  11663.575  12997.875
# 서울   18189.0  18997.250000  19282.600000  20663.500  21425.250  22889.350
# 세종    7601.0   8085.333333   8641.227273   8860.500   9133.025  10354.850
# 울산    8090.0   8361.666667   9273.336364  10208.550  11327.525  10241.400
# 인천   10204.0  10074.833333  10276.845455  10532.500  10749.475  11273.900
# 전남    5678.0   5718.916667   6109.263636   6488.625   7245.700   7789.100
# 전북    6282.0   6362.333333   6623.290909   6417.950   7074.650   7625.750
# 제주    7674.0   7855.166667   7465.327273   9129.175  10907.325  11890.725
# 충남    6365.0   6681.583333   7024.490909   7330.675   7455.800   8012.675
# 충북    6589.0   6620.000000   6699.572727   6770.225   6770.225   7874.075
#
# 연도        2019       2020     2021
# 지역명
# 강원    8141.650   9331.300  10355.4
# 경기   14468.850  14383.325  14414.4
# 경남    9870.850  10160.700   9860.4
# 경북    8856.650   9544.975  10345.5
# 광주   11822.800  12500.125  12906.3
# 대구   13852.025  15145.075  15354.9
# 대전   11777.700  11094.050  10579.8
# 부산   13116.400  13247.575  14038.2
# 서울   26131.050  26910.125  28267.8
# 세종   11078.925  11355.300  12533.4
# 울산   10022.100  12202.850  13787.4
# 인천   12634.875  14674.000  15602.4
# 전남    7902.400   8696.875   9329.1
# 전북    8196.650   8317.100   8708.7
# 제주   12137.950  14540.900  17156.7
# 충남    8606.950   8856.100   9111.3
# 충북    7574.600   7959.600   8527.2

# %%
temp = result.pivot_table(index='연도', values='평당분양가격', columns='지역명').T.plot()
temp.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.show()

# %%
result
# Out:
#      지역명   평당분양가격    연도   월
# 0     서울  18189.0  2013  12
# 1     부산   8111.0  2013  12
# 2     대구   8080.0  2013  12
# 3     인천  10204.0  2013  12
# 4     광주   6098.0  2013  12
# ...   ..      ...   ...  ..
# 5415  전북   8708.7  2021   1
# 5420  전남   9329.1  2021   1
# 5425  경북  10345.5  2021   1
# 5430  경남   9860.4  2021   1
# 5435  제주  17156.7  2021   1
#
# [1445 rows x 4 columns]

# %%
plt.figure(figsize=(10,4))
sns.lineplot(x='연도', y='평당분양가격', data=result)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='연도', y='평당분양가격', data=result, palette='husl').set_title('연도별 평당분양가격(평균)')
plt.savefig('data/ch13_example1-5.png')

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='지역명', y='평당분양가격', data=result, ci=None).set_title('지역별 평당분양가격(평균)')
plt.savefig('data/ch13_example1-6.png')

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x='연도', y='평당분양가격', data=result, palette='husl')
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.countplot(x='연도', data=result, palette="viridis").set_title("연도별 평당가격 관측수")
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.countplot(x='지역명', data=result, palette='crest').set_title("지역별 평당가격 관측수")
plt.show()

# %%
result.corr()
# Out:
#           평당분양가격        연도         월
# 평당분양가격  1.000000  0.359418  0.029701
# 연도      0.359418  1.000000 -0.062838
# 월       0.029701 -0.062838  1.000000

# %%
plt.figure(figsize=(7,5))
sns.heatmap(result.corr(), vmin=-1, vmax=1, annot=True, cmap='mako', fmt='.2f')
plt.savefig('data/ch13_example1-7.png')

# %%
g = sns.FacetGrid(result, col='연도', hue='연도', col_wrap=3, palette='husl')
g.map(plt.hist, '평당분양가격')
g.set_axis_labels(y_var='count')
plt.savefig('data/ch13_example1-8.png')
