# %% [markdown]
# **21-03-10 python 12_데이터프레임과 시리즈(Pandas) (c)cherryuki (ji)**

# %% [markdown]
# # 판다스 연습문제

# %%
import pandas as pd
import numpy as np
import random
from statsmodels.api import datasets
iris_df = datasets.get_rdataset("iris", package="datasets").data
iris_df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#1단계: iris 데이터에서 결측치를 인위적으로 random하게 열마다 20씩 결측치를 할당한다
print(random.sample(range(len(iris_df)),20), end=' ')
# Out:
# [68, 130, 29, 43, 66, 74, 86, 132, 93, 104, 106, 100, 26, 142, 34, 25, 131, 4, 42, 136]

# %%
rownum = {0:random.sample(range(len(iris_df)), 20), 1:random.sample(range(len(iris_df)), 20), 
          2:random.sample(range(len(iris_df)), 20), 3:random.sample(range(len(iris_df)), 20)}
print(rownum)
# Out:
# {0: [28, 118, 1, 122, 139, 84, 34, 86, 87, 55, 116, 30, 112, 106, 113, 4, 35, 91, 96, 27], 1: [110, 95, 60, 28, 58, 66, 99, 45, 79, 56, 7, 117, 54, 126, 39, 71, 77, 115, 22, 145], 2: [26, 103, 146, 123, 4, 15, 132, 120, 77, 73, 98, 72, 14, 32, 128, 95, 2, 17, 21, 85], 3: [108, 114, 124, 103, 113, 25, 116, 85, 74, 122, 14, 4, 91, 60, 53, 73, 92, 102, 39, 34]}

# %%
#방법1
for (idx, row) in rownum.items():
    iris_df.iloc[row, idx] = np.nan
iris_df.isnull().sum()
# Out:
# Sepal.Length    20
# Sepal.Width     20
# Petal.Length    20
# Petal.Width     20
# Species          0
# dtype: int64

# %%
#방법2
for col in range(iris_df.shape[1]-1):
    iris_df.iloc[random.sample(range(len(iris_df)),20),col] = np.nan
iris_df.isna().sum()
# Out:
# Sepal.Length    20
# Sepal.Width     20
# Petal.Length    20
# Petal.Width     20
# Species          0
# dtype: int64

# %%
#2단계: 결측치가 있는 iris데이터를 출력
iris_df_grouped = iris_df.groupby(iris_df.Species)
iris_df_grouped.count()
# Out:
#             Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Species
# setosa                42           46            43           40
# versicolor            44           40            39           44
# virginica             44           44            48           46

# %%
iris_df[iris_df['Sepal.Length'].isnull()] #20개
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 2             NaN          3.2           1.3          NaN      setosa
# 3             NaN          3.1           1.5          0.2      setosa
# 4             NaN          3.6           1.4          0.2      setosa
# 14            NaN          4.0           1.2          NaN      setosa
# 17            NaN          3.5           1.4          0.3      setosa
# 20            NaN          3.4           1.7          0.2      setosa
# 26            NaN          3.4           1.6          0.4      setosa
# 30            NaN          3.1           1.6          0.2      setosa
# 51            NaN          NaN           NaN          1.5  versicolor
# 59            NaN          2.7           3.9          1.4  versicolor
# 66            NaN          3.0           4.5          1.5  versicolor
# 72            NaN          2.5           4.9          1.5  versicolor
# 87            NaN          2.3           NaN          1.3  versicolor
# 88            NaN          3.0           4.1          1.3  versicolor
# 100           NaN          3.3           6.0          2.5   virginica
# 112           NaN          3.0           5.5          2.1   virginica
# 117           NaN          3.8           6.7          2.2   virginica
# 123           NaN          2.7           4.9          1.8   virginica
# 148           NaN          NaN           5.4          2.3   virginica
# 149           NaN          3.0           5.1          NaN   virginica

# %%
iris_df[iris_df['Sepal.Width'].isnull()].head()
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 0            5.1          NaN           NaN          0.2      setosa
# 1            4.9          NaN           1.4          0.2      setosa
# 12           4.8          NaN           NaN          0.1      setosa
# 42           4.4          NaN           1.3          0.2      setosa
# 51           NaN          NaN           NaN          1.5  versicolor

# %%
iris_df[iris_df['Petal.Length'].isnull()].head()
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0            5.1          NaN           NaN          0.2  setosa
# 12           4.8          NaN           NaN          0.1  setosa
# 19           5.1          3.8           NaN          NaN  setosa
# 31           5.4          3.4           NaN          0.4  setosa
# 38           4.4          3.0           NaN          0.2  setosa

# %%
iris_df[iris_df['Petal.Width'].isnull()].head()
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 2            NaN          3.2           1.3          NaN  setosa
# 13           4.3          3.0           1.1          NaN  setosa
# 14           NaN          4.0           1.2          NaN  setosa
# 18           5.7          3.8           1.7          NaN  setosa
# 19           5.1          3.8           NaN          NaN  setosa

# %%
#3단계: 결측치를 열평균으로 대체된 iris데이터를 출력
iris_df.mean()
# Out:
# Sepal.Length    5.857692
# Sepal.Width     3.081538
# Petal.Length    3.786923
# Petal.Width     1.241538
# dtype: float64

# %%
iris_df = iris_df.fillna(value=iris_df.mean())
iris_df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0      5.100000     3.081538      3.786923     0.200000  setosa
# 1      4.900000     3.081538      1.400000     0.200000  setosa
# 2      5.857692     3.200000      1.300000     1.241538  setosa
# 3      5.857692     3.100000      1.500000     0.200000  setosa
# 4      5.857692     3.600000      1.400000     0.200000  setosa

# %%
iris_df.groupby(iris_df.Species).count()
# Out:
#             Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %% [markdown]
# ## 연습문제 실습형

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
#1. iris 데이터에서 처음 다섯개 행만 출력하세요
iris.head()
iris[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#2. iris 데이터를 독립변수 X와 종속변수 y로 나누세요. 종속변수는 species 열입니다.
X = iris.iloc[:, :-1]
y = iris.iloc[:, -1]

# %%
type(X), type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
y.to_frame() #데이터프레임으로 바꿔도 되고 안바꿔도 문제 없음
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
#3. iris 데이터에서 처음 50개행을 빼내서 temp변수에 저장하세요
temp = iris[:50]

# %%
#4.  3번에서 선택한 데이터프레임의 요약정보를 출력하세요. 모든 열에 대해 요약정보가출력되어야 합니다.
temp.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count       50.00000    50.000000     50.000000    50.000000      50
# unique           NaN          NaN           NaN          NaN       1
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean         5.00600     3.428000      1.462000     0.246000     NaN
# std          0.35249     0.379064      0.173664     0.105386     NaN
# min          4.30000     2.300000      1.000000     0.100000     NaN
# 25%          4.80000     3.200000      1.400000     0.200000     NaN
# 50%          5.00000     3.400000      1.500000     0.200000     NaN
# 75%          5.20000     3.675000      1.575000     0.300000     NaN
# max          5.80000     4.400000      1.900000     0.600000     NaN

# %%
#5. versicolor종의 데이터만 iris_versicolor변수에 저장하세요
iris_versicolor = iris[iris.species=='versicolor']
iris_versicolor.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor

# %%
#6. 2번의 X와 y변수를 합해서 iris_df데이터 프레임으로 만드세요
iris_df = pd.concat([X,y], axis=1)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#7. iris데이터의 각 열 평균값을 출력
iris.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
#8. iris 데이터의 각 열들 사이의 상관계수를 출력
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.heatmap(iris.corr(), annot=True, cmap="Blues", fmt=".1f")
plt.show()

# %%
#9. iris 데이터에서 각 요소들과 변수별 평균과의 차이를 출력(처음 다섯개 행 출력)
iris.iloc[:,:4].apply(lambda x:x-iris.mean(), axis=1).head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.743333     0.442667        -2.358    -0.999333
# 1     -0.943333    -0.057333        -2.358    -0.999333
# 2     -1.143333     0.142667        -2.458    -0.999333
# 3     -1.243333     0.042667        -2.258    -0.999333
# 4     -0.843333     0.542667        -2.358    -0.999333

# %%
#10. iris 데이터의 종별 평균
species_mean = iris.groupby(iris.species).mean()
species_mean
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
#11. iris 데이터에서 각 요소들과 종별 변수의 평균과의 차이를 출력(각 종별로 3개씩 출력)
species_mean.loc['setosa', :]
# Out:
# sepal_length    5.006
# sepal_width     3.428
# petal_length    1.462
# petal_width     0.246
# Name: setosa, dtype: float64

# %%
iris.apply(lambda x:x-species_mean.loc[x.species,:], axis=1)
# Out:
#      petal_length  petal_width  sepal_length  sepal_width  species
# 0          -0.062       -0.046         0.094        0.072      NaN
# 1          -0.062       -0.046        -0.106       -0.428      NaN
# 2          -0.162       -0.046        -0.306       -0.228      NaN
# 3           0.038       -0.046        -0.406       -0.328      NaN
# 4          -0.062       -0.046        -0.006        0.172      NaN
# ..            ...          ...           ...          ...      ...
# 145        -0.352        0.274         0.112        0.026      NaN
# 146        -0.552       -0.126        -0.288       -0.474      NaN
# 147        -0.352       -0.026        -0.088        0.026      NaN
# 148        -0.152        0.274        -0.388        0.426      NaN
# 149        -0.452       -0.226        -0.688        0.026      NaN
#
# [150 rows x 5 columns]

# %%
iris.apply(lambda x:x-species_mean.loc[x.species,:], axis=1).groupby(iris.species).head(3)
# Out:
#      petal_length  petal_width  sepal_length  sepal_width  species
# 0          -0.062       -0.046         0.094        0.072      NaN
# 1          -0.062       -0.046        -0.106       -0.428      NaN
# 2          -0.162       -0.046        -0.306       -0.228      NaN
# 50          0.440        0.074         1.064        0.430      NaN
# 51          0.240        0.174         0.464        0.430      NaN
# 52          0.640        0.174         0.964        0.330      NaN
# 100         0.448        0.474        -0.288        0.326      NaN
# 101        -0.452       -0.126        -0.788       -0.274      NaN
# 102         0.348        0.074         0.512        0.026      NaN

# %%
iris.apply(lambda x:x-species_mean.loc[x.species,:], axis=1).groupby(iris.species).take(range(3))
# Out:
#                 petal_length  petal_width  sepal_length  sepal_width  species
# species
# setosa     0          -0.062       -0.046         0.094        0.072      NaN
#            1          -0.062       -0.046        -0.106       -0.428      NaN
#            2          -0.162       -0.046        -0.306       -0.228      NaN
# versicolor 50          0.440        0.074         1.064        0.430      NaN
#            51          0.240        0.174         0.464        0.430      NaN
#            52          0.640        0.174         0.964        0.330      NaN
# virginica  100         0.448        0.474        -0.288        0.326      NaN
#            101        -0.452       -0.126        -0.788       -0.274      NaN
#            102         0.348        0.074         0.512        0.026      NaN

# %%
#참고: Why 열 순서가 변경되는지(열 개수가 다름;4개에서 5개를 뺌)
iris_mean_by_species = iris.groupby(iris.species).mean()
print(iris_mean_by_species.index)
print(iris_mean_by_species.columns)
print(iris_mean_by_species.loc['setosa',:])
# Out:
# Index(['setosa', 'versicolor', 'virginica'], dtype='object', name='species')
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')
# sepal_length    5.006
# sepal_width     3.428
# petal_length    1.462
# petal_width     0.246
# Name: setosa, dtype: float64

# %%
a = iris_mean_by_species.loc['setosa',:]
b = iris.loc[0]
print(a)
print()
print(b[:-1])
print()
print(a-b[:-1])
print()
print(a-b) #4개에서 5개를 빼면 순서가 뒤바뀜
# Out:
# sepal_length    5.006
# sepal_width     3.428
# petal_length    1.462
# petal_width     0.246
# Name: setosa, dtype: float64
#
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object
#
# sepal_length   -0.094
# sepal_width    -0.072
# petal_length    0.062
# petal_width     0.046
# dtype: object
#
# petal_length    0.062
# petal_width     0.046
# sepal_length   -0.094
# sepal_width    -0.072
# species           NaN
# dtype: object
