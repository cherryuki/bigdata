# %% [markdown]
# # Project

# %% [markdown]
# ## 01. 자료수집
# ### 1) 뉴스 기사 웹크롤링
# ### 2) 식품 리포트 위주 크롤링
# - pdf파일은 어려움(txt파일 가능)
#
# ### 3) 통계청, data 위주 크롤링

# %%
#식음료신문: http://www.thinkfood.co.kr/news/articleList.html?sc_section_code=S1N1&view_type=sm
#div.list-titles > a 기사링크
#기사제목: div.list-titles > a > strong 
#기사 페이지 기사 제목: div.article-head-title
#기사 내용: article.article-veiw-body

#농수축산신문(식품): http://www.aflnews.co.kr/news/articleList.html?sc_section_code=S1N5&view_type=sm
#기사제목: h4.titles > a 텍스트
#기사 링크: h4.titles > a href
#기사 내용: #article-view-content-div

# %%
#식음료신문: http://www.thinkfood.co.kr/news/articleList.html?sc_section_code=S1N1&view_type=sm
#div.list-titles > a 기사링크
#기사제목: div.list-titles > a > strong 
#기사 페이지 기사 제목: div.article-head-title
#기사 내용: article.article-veiw-body
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
result_df = pd.DataFrame(None, columns = ['title', 'link', 'date', 'news'])
num=1
index=0
for num in range(1, 150):
    url = 'http://www.thinkfood.co.kr/news/articleList.html?page='+str(num)+'&total=25340&sc_section_code=S1N1&sc_sub_section_code=&sc_serial_code=&sc_area=&sc_level=&sc_article_type=&sc_view_level=&sc_sdate=&sc_edate=&sc_serial_number=&sc_word=&sc_word2=&sc_andor=&sc_order_by=E&view_type=sm'
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    link_list = soup.select('div.list-titles > a')
    link_list = ['http://www.thinkfood.co.kr'+link.attrs['href'] for link in link_list]
    date_list = soup.select('div.list-dated')
    date_list = [date.text for date in date_list]
    date_list = ' '.join(date_list)
    date_list = re.findall(r'\d{4}-\d{2}-\d{2}', date_list)
    title_list = soup.select('div.list-titles > a > strong')
    title_list = [title.text for title in title_list]
    for i in range(len(date_list)):
        html = requests.get(link_list[i])
        news_soup = BeautifulSoup(html.content, 'html.parser')
        news_list = news_soup.select('article.article-veiw-body')
        news_list = [news.text for news in news_list]
        result_df.loc[index] = [title_list[i], link_list[i], date_list[i], news_list]
        index+=1
    num+=1

# %%
result_df.to_csv('01_식음료신문.csv', sep=',')

# %%
#농수축산신문(식품): http://www.aflnews.co.kr/news/articleList.html?page=1&total=5118&box_idxno=&sc_section_code=S1N5&view_type=sm
#기사제목: h4.titles > a 텍스트
#기사 링크: h4.titles > a href
#기사 내용: #article-view-content-div
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
result_df2 = pd.DataFrame(None, columns = ['title', 'link', 'date', 'news'])
num=1
index=0
for num in range(1,50):
    url = 'http://www.aflnews.co.kr/news/articleList.html?page='+str(num)+'&total=5118&box_idxno=&sc_section_code=S1N5&view_type=sm'
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    link_list = soup.select('h4.titles > a')
    link_list = ['http://www.aflnews.co.kr'+link.attrs['href'] for link in link_list]
    title_list = soup.select('h4.titles > a')
    title_list = [title.text for title in title_list]
    date_list = soup.select('span.byline')
    date_list = [date.text for date in date_list]
    date_list = ' '.join(date_list)
    date_list = re.findall(r'\d{4}.\d{2}.\d{2}', date_list)
    for i in range(len(date_list)):
        html = requests.get(link_list[i])
        news_soup = BeautifulSoup(html.content, 'html.parser')
        news_date = news_soup.select_one('i.icon-clock-o')
        news_list = news_soup.select('article#article-view-content-div')
        news_list = [news.text for news in news_list]
        result_df2.loc[index] = [title_list[i], link_list[i], date_list[i], news_list]
        index+=1
    num+=1

# %%
result_df2.to_csv('02_농수축산신문.csv', sep=',')

# %%
#농수축산신문 이슈플러스
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
result_df3 = pd.DataFrame(None, columns = ['title', 'link', 'date', 'news'])
num=1
index=0
for num in range(1,26):
    url = 'http://www.aflnews.co.kr/news/articleList.html?page='+str(num)+'&total=514&box_idxno=&sc_section_code=S1N11&view_type=sm'
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    link_list = soup.select('h4.titles > a')
    link_list = ['http://www.aflnews.co.kr'+link.attrs['href'] for link in link_list]
    title_list = soup.select('h4.titles > a')
    title_list = [title.text for title in title_list]
    date_list = soup.select('span.byline')
    date_list = [date.text for date in date_list]
    date_list = ' '.join(date_list)
    date_list = re.findall(r'\d{4}.\d{2}.\d{2}', date_list)
    for i in range(len(date_list)):
        html = requests.get(link_list[i])
        news_soup = BeautifulSoup(html.content, 'html.parser')
        news_date = news_soup.select_one('i.icon-clock-o')
        news_list = news_soup.select('article#article-view-content-div')
        news_list = [news.text for news in news_list]
        result_df3.loc[index] = [title_list[i], link_list[i], date_list[i], news_list]
        index+=1
    num+=1

# %%
result_df3.to_csv('02_농수축산신문_축산.csv', sep=',')

# %%
#식품외식경제: http://www.aflnews.co.kr/news/articleList.html?page=1&total=5118&box_idxno=&sc_section_code=S1N5&view_type=sm
#기사제목: div.list-titles > a 텍스트
#기사 링크: div.list-titles > a href
#날짜: div.list-dated \d{4}-\d{2}-\d{2}
#기사 내용: #article-view-content-div
result_df4 = pd.DataFrame(None, columns = ['title', 'link', 'date', 'news'])
num=1
index=0
for num in range(1, 150):
    url = 'http://www.foodbank.co.kr/news/articleList.html?page='+str(num)+'&total=21032&sc_section_code=&sc_sub_section_code=S2N1&sc_serial_code=&sc_area=&sc_level=&sc_article_type=&sc_view_level=&sc_sdate=&sc_edate=&sc_serial_number=&sc_word=&sc_word2=&sc_andor=&sc_order_by=E&view_type=sm&sc_multi_code='
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    link_list = soup.select('div.list-titles > a')
    link_list = ['http://www.foodbank.co.kr'+link.attrs['href'] for link in link_list]
    date_list = soup.select('div.list-dated')
    date_list = [date.text for date in date_list]
    date_list = ' '.join(date_list)
    date_list = re.findall(r'\d{4}-\d{2}-\d{2}', date_list)
    title_list = soup.select('div.list-titles > a > strong')
    title_list = [title.text for title in title_list]
    for i in range(len(date_list)):
        html = requests.get(link_list[i])
        news_soup = BeautifulSoup(html.content, 'html.parser')
        news_list = news_soup.select('#article-view-content-div')
        news_list = [news.text for news in news_list]
        result_df4.loc[index] = [title_list[i], link_list[i], date_list[i], news_list]
        index+=1
    num+=1

# %%
result_df4.to_csv('03_식품외식경제.csv', sep=',')

# %%
#식품저널뉴스(전체): http://www.aflnews.co.kr/news/articleList.html?page=1&total=5118&box_idxno=&sc_section_code=S1N5&view_type=sm
#기사제목: h4.titles > a 텍스트
#기사 링크: h4.titles > a href
#날짜 span.byline \d{4}.\d{2}.\d{2}
#기사 내용: #article-view-content-div
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
result_df5 = pd.DataFrame(None, columns = ['title', 'link', 'date', 'news'])
num=1
index=0
for num in range(1,300):
    url = 'http://www.foodnews.co.kr/news/articleList.html?page='+str(num)+'&total=63398&box_idxno=&sc_section_code=S1N1&view_type=sm'
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    link_list = soup.select('h4.titles > a')
    link_list = ['http://www.aflnews.co.kr'+link.attrs['href'] for link in link_list]
    title_list = soup.select('h4.titles > a')
    title_list = [title.text for title in title_list]
    date_list = soup.select('span.byline')
    date_list = [date.text for date in date_list]
    date_list = ' '.join(date_list)
    date_list = re.findall(r'\d{4}.\d{2}.\d{2}', date_list)
    for i in range(len(date_list)):
        html = requests.get(link_list[i])
        news_soup = BeautifulSoup(html.content, 'html.parser')
        news_date = news_soup.select_one('i.icon-clock-o')
        news_list = news_soup.select('article#article-view-content-div')
        news_list = [news.text for news in news_list]
        result_df5.loc[index] = [title_list[i], link_list[i], date_list[i], news_list]
        index+=1
    num+=1
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-822681e5708f> in <module>
#      24     date_list = re.findall(r'\d{4}.\d{2}.\d{2}', date_list)
#      25     for i in range(len(date_list)):
# ---> 26         html = requests.get(link_list[i])
#      27         news_soup = BeautifulSoup(html.content, 'html.parser')
#      28         news_date = news_soup.select_one('i.icon-clock-o')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
result_df5.to_csv('04_식품저널뉴스.csv', sep=',')

# %%
result_df5
# Out:
#                                                 title  \
# 0                        자상한 기업 ‘이마트’, 백년가게 ‘태극당’과 협업
# 1                      국립보건연구원, 항생제 내성 분야 WHO 협력센터 지정
# 2                           식품진흥원, 맞춤형 식이설계 플랫폼 구축 추진
# 3                 농진청, ‘유가공 목장 알리미’ 참여 낙농가 내달 9일까지 모집
# 4                     이달의 A-벤처스에 농산물 직거래 앱 개발 ’에이임팩트‘
# 5                     특별여행주의보 발령 지역 해외제조업소 현지 위생평가 유예
# 6                      [신상품] 대상 ‘널 응원해’ 롯데제과 ‘뻥쿠아즈’ 외
# 7                        풀무원 ‘뮤지엄김치간’, 어린이 김치학교 랜선 운영
# 8                                풀무원푸드머스, 롯데하이마트와 MOU
# 9           야채 1종을 사용한 소시지 제품의 이름 일부로 ‘야채’를 표시해도 되나요?
# 10                           조미식품, 음료류 ‘정제형태’ 제조 허용한다
# 11           신동원 농심 부회장 “아버지의 위대한 유산 ‘농심 철학’ 이어가겠습니다”
# 12                           농지 취득 심사ㆍ사후점검 강화로 투기 막는다
# 13                     한미양행, 암환자 치료기 및 관리기  식단 상품화 추진
# 14                       파리바게뜨 10년 이상 가맹점, 계약 갱신 쉬워진다
# 15                        수산식품산업 2025년 13조8천억원 규모로 육성
# 16                         교촌에프앤비, 조은기 총괄사장 ‘대표이사’ 선임
# 17                        해마로푸드서비스, ‘맘스터치앤컴퍼니’로 사명 변경
# 18                       실용화재단, 종자박람회 참가사 4월 17일까지 모집
# 19          서삼석 의원, 유휴농지 실태조사 의무화ㆍ식량자급 제고 위한 법 개정안 발의
# 20               UN 푸드시스템 정상회의 앞두고 ‘지속가능 푸드시스템‘ 의견 수렴
# 21         한국야쿠르트 회사이름 ‘hy’로 바꾸고, 물류ㆍ채널ㆍ플랫폼까지 사업영역 확대
# 22                            농식품부, 국민과 함께 규제개선 과제 발굴
# 23  [신상품] CJ제일제당 ‘막걸리와 어울리는 메뉴 4종’ 매일유업 ‘골든밀크’ 오뚜기...
# 24                   쌀, 고구마 등 4개 식량작물 신품종 소비자 만족도 평가
# 25                    식약처-임상영양학회, 환자 식사관리식품 제조업체 기술자문
# 26                               샘표 “맛있는 추억을 그려주세요”
# 27                            롯데칠성음료, 천사무료급식소에 천만원 기부
# 8   [\r\n\t\t\r\n\t\t\t전남도농업기술원(원장 박민수)과 강진군은 고품질 ...
# 9   [\n   농협경북지역본부(본부장 채원봉)와 농협의성군지부(지부장 천우석)는 지난 ...
# 10  [\n  -나눔축산…상생·협력 계기 마련  무진장축협(조합장 권광열)이 설 명절을 ...
# 11  [\n▲ 농협광주지역본부는 지난 1일 광주지방경찰청과 함께 우리고장 먹거리 소비촉진...
# 12  [\n  울산 온산농협(조합장 정차길)은 지난 4일 입춘을 맞아 조합 본점 예금창구...
# 13  [\n  부산 명지농협(조합장 김선원)은 올해 예수금 1250억원, 대출금 900억...
# 14  [\n  동고령농협(조합장 권태휘)은 지난달 30일 조합 회의실에서 곽용환 군수, ...
# 15  [\n  밀양축협(조합장 박재종)은 지난해 예수금은 전년대비 153억원 늘어난 18...
# 16  [\n   -경영회생지원사업 1030억 투입  한국농어촌공사 전북지역본부(본부장 이...
# 17  [\n  -경제사업 31.7% 성장 당기순익 6억2800만원  -축산물판매 300억...
# 18  [\n  평창영월정선축협(조합장 김영교)은 지난달 30일 평창문화예술회관에서 임원 ...
# 19  [\n  -‘조랑우랑 한우이야기’와 강남 축산물전문매장 유통판매사업 순항  보은축협...
# 20  [\n  양평축협(조합장 윤철수)은 지난 1일 양평군 여성회관에서 이주호 양평군지부...
# 21  [\n  “축산업이 어려운 만큼 이를 극복하기 위해서는 업무의 연속성이 유지돼야 한...
# 22  [\n  -금정농협 상호금융 여 · 수신 1조1400억원  부산 금정농협(조합장 송...
# 23  [\r\n\t\t\r\n\t\t\t당진축협(조합장 차선수)은 지난 5일 당진농업기술...
# 24  [\n  -도시형 최우수조합으로 우뚝  -영천축협, 순익 15억원…창립이래 최고 실...
# 25  [\n  농협경남지역본부(본부장 전억수)는 지난 5일 지역본부 대회의실에서 지역본부...
# 26  [\n  영주축협(조합장 서병국)은 지난달 31일 영주축협 한우프라자에서 김주영 영...
# 27  [\n  -저온창고 · 가공공장 설립 박차  고령 쌍림농협(조합장 박대성)은 지난달...
# 28  [\n  -요양원 설립…복지향상 주력  지난 6일 치러진 제천농협 조합장 선거에서 ...
# 29  [\n  농협강원지역본부(본부장 채형석)는 김화농협(조합장 엄충국) 토마토공선출하회...
# 30  [\n  청주축협(조합장 유인종)은 지난 4일 본점 대회의실에서 정기총회를 개최하고...
# 31  [\n  -여성이사제 도입 · 투명 경영 약속   진천축협 조합장 보궐선거에서 박승...
# 32  [\n  정읍농협(조합장 유남영)은 지난달 28일 조합 대회의실에서 ‘조합원자녀 장...
# 33  [\n  한국농어촌공사 무안신안지사(지사장 김철수)는 지난 4일 지사 회의실에서 설...
# 34  [\n  설 이후 종계와 원종계에 대한 감축사업이 시행될 것으로 알려지면서 벌써부터...
# 35  [\n농촌진흥청 국립축산과학원(원장 장원경)은 민족 고유의 명절인 설을 앞두고 관내...
# 36  [\n▲ 매일유업이 새롭게 선보인 '유기농 아이치즈' 제품 3종으로 '닥터치즈'라는...
# 37  [\n  일반적으로 사골국의 열량이 높다고 알려져 있으나 실제 열량 조사 결과 저지...
# 38  [\n  ‘대한민국 축산물 유통 No.1’   농협 축산유통부는 최근 ‘농가에게 제...
# 39  [\n  1.(주)국제환경기술은 지난 4일 경남 양산시에 위치한 양돈장에 고액분리기...
