# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import seaborn as sns
#한글 설정
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False) # y축

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/인구동태건수_및_동태율_추이_출생_사망_혼인_이혼__2010-2021(연도별).csv')
df
# Out:
#                  기본항목별        2010        2011        2012        2013  \
# 0              출생아수(명)  470171.000  471265.000  484550.000  436455.000
# 1              사망자수(명)  255405.000  257396.000  267221.000  266257.000
# 2            자연증가건수(명)  214766.000  213869.000  217329.000  170198.000
# 3            조출생률(천명당)       9.400       9.400       9.600       8.600
# 4            조사망률(천명당)       5.100       5.100       5.300       5.300
# 5           자연증가율(천명당)       4.300       4.300       4.300       3.400
# 6             합계출산율(명)       1.226       1.244       1.297       1.187
# 7              출생성비(명)     106.900     105.700     105.700     105.300
# 8       영아사망률(출생아 천명당)       3.200       3.000       2.900       3.000
# 9              혼인건수(건)  326104.000  329087.000  327073.000  322807.000
# 10           조혼인율(천명당)       6.500       6.600       6.500       6.400
# 11             이혼건수(건)  116858.000  114284.000  114316.000  115292.000
# ...

# %%
df = df.T.reset_index()
df = df.rename(columns=df.iloc[0])
df = df.drop([df.index[0]])
df
# Out:
#       기본항목별 출생아수(명) 사망자수(명) 자연증가건수(명) 조출생률(천명당) 조사망률(천명당) 자연증가율(천명당) 합계출산율(명)  \
# 1      2010  470171  255405    214766       9.4       5.1        4.3    1.226
# 2      2011  471265  257396    213869       9.4       5.1        4.3    1.244
# 3      2012  484550  267221    217329       9.6       5.3        4.3    1.297
# 4      2013  436455  266257    170198       8.6       5.3        3.4    1.187
# 5      2014  435435  267692    167743       8.6       5.3        3.3    1.205
# 6      2015  438420  275895    162525       8.6       5.4        3.2    1.239
# 7      2016  406243  280827    125416       7.9       5.5        2.5    1.172
# 8      2017  357771  285534     72237         7       5.6        1.4    1.052
# 9      2018  326822  298820     28002       6.4       5.8        0.5    0.977
# 10     2019  302676  295110      7566       5.9       5.7        0.1    0.918
# 11  2020 p)  272400  305100    -32700       5.3       5.9       -0.6     0.84
#
# ...

# %%
df.iloc[10,0]=2020
df.iloc[10][df.iloc[10]=='-']=0

# %%
for i in range(df.shape[1]):
    df.iloc[:, i] = pd.to_numeric(df.iloc[:, i])

# %%
df.describe()
# Out:
#              기본항목별        출생아수(명)        사망자수(명)      자연증가건수(명)  조출생률(천명당)  \
# count    11.000000      11.000000      11.000000      11.000000  11.000000
# mean   2015.000000  400200.727273  277750.636364  122450.090909   7.881818
# std       3.316625   73581.679486   16806.347612   89743.778738   1.505867
# min    2010.000000  272400.000000  255405.000000  -32700.000000   5.300000
# 25%    2012.500000  342296.500000  266739.000000   50119.500000   6.700000
# 50%    2015.000000  435435.000000  275895.000000  162525.000000   8.600000
# 75%    2017.500000  454295.500000  290322.000000  192033.500000   9.000000
# max    2020.000000  484550.000000  305100.000000  217329.000000   9.600000
#
#        조사망률(천명당)  자연증가율(천명당)   합계출산율(명)     출생성비(명)  영아사망률(출생아 천명당)  \
# count  11.000000   11.000000  11.000000   11.000000       11.000000
# mean    5.454545    2.427273   1.123364  105.572727        2.627273
# std     0.269680    1.793929   0.151879    0.579812        0.884410
# ...

# %%
df
# Out:
#     기본항목별   출생아수(명)   사망자수(명)  자연증가건수(명)  조출생률(천명당)  조사망률(천명당)  자연증가율(천명당)  \
# 1    2010  470171.0  255405.0   214766.0        9.4        5.1         4.3
# 2    2011  471265.0  257396.0   213869.0        9.4        5.1         4.3
# 3    2012  484550.0  267221.0   217329.0        9.6        5.3         4.3
# 4    2013  436455.0  266257.0   170198.0        8.6        5.3         3.4
# 5    2014  435435.0  267692.0   167743.0        8.6        5.3         3.3
# 6    2015  438420.0  275895.0   162525.0        8.6        5.4         3.2
# 7    2016  406243.0  280827.0   125416.0        7.9        5.5         2.5
# 8    2017  357771.0  285534.0    72237.0        7.0        5.6         1.4
# 9    2018  326822.0  298820.0    28002.0        6.4        5.8         0.5
# 10   2019  302676.0  295110.0     7566.0        5.9        5.7         0.1
# 11   2020  272400.0  305100.0   -32700.0        5.3        5.9        -0.6
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='기본항목별', y='출생아수(명)', data=df)
sns.pointplot(x='기본항목별', y='사망자수(명)', data=df)
sns.pointplot(x='기본항목별', y='자연증가건수(명)', data=df)
# Out:
# <AxesSubplot:xlabel='기본항목별', ylabel='자연증가건수(명)'>

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x='기본항목별', y='혼인건수(건)', data=df)
sns.barplot(x='기본항목별', y='이혼건수(건)', data=df)
#sns.pointplot(x='기본항목별', y='자연증가건수(명)', data=df)
# Out:
# <AxesSubplot:xlabel='기본항목별', ylabel='이혼건수(건)'>

# %%
sns.pointplot(x='기본항목별', y='조혼인율(천명당)', data=df)
sns.pointplot(x='기본항목별', y='조이혼율(천명당)', data=df, markers='^', color='red')
# Out:
# <AxesSubplot:xlabel='기본항목별', ylabel='조이혼율(천명당)'>

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax2 = ax1.twinx()
ax1 = sns.barplot(x='기본항목별', y='이혼건수(건)', data=df, ax=ax1)
ax2 = sns.pointplot(x='기본항목별', y='조이혼율(천명당)', data=df, ax=ax2)
#plt.title('실업자 및 실업률')
#plt.savefig('data2/그래프1_실업자_실업률_2010-2020.jpg')

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax2 = ax1.twinx()
ax1 = sns.barplot(x='기본항목별', y='혼인건수(건)', data=df, ax=ax1)
ax2 = sns.pointplot(x='기본항목별', y='조혼인율(천명당)', data=df, ax=ax2)
ax2 = sns.pointplot(x='기본항목별', y='조이혼율(천명당)', data=df, ax=ax2, markers='^', color='red')
ax1.set_xlabel('연도')
# Out:
# Text(0.5, 0, '연도')

# %%
df1 = pd.read_csv('data/인구동향_출생_사망_혼인_이혼__2019-2021(월별).csv', encoding='cp949')
df1
# Out:
#               시점 행정구역별(1)  출생아수(명)  조출생률(천명당)  사망자수(명)  조사망률(천명당)  자연증가건수(명)  \
# 0       2019. 01       전국    30271        6.9    27366        6.3       2905
# 1       2019. 01    서울특별시     5248        6.4     3975        4.9       1273
# 2       2019. 01    부산광역시     1650        5.7     2161        7.5       -511
# 3       2019. 01    대구광역시     1253        6.0     1331        6.4        -78
# 4       2019. 01    인천광역시     1946        7.8     1375        5.5        571
# ..           ...      ...      ...        ...      ...        ...        ...
# 445  2021. 01 p)     전라북도      739        4.9     1313        8.6       -574
# 446  2021. 01 p)     전라남도      882        5.6     1564       10.0       -682
# 447  2021. 01 p)     경상북도     1131        5.1     1868        8.4       -737
# 448  2021. 01 p)     경상남도     1506        5.3     2034        7.2       -528
# 449  2021. 01 p)  제주특별자치도      359        6.3      338        5.9         21
#
# ...

# %%
df1['시점'] = df1['시점'].apply(lambda x:x.replace('p)', '').replace(' ', ''))
df1['시점'] = df1['시점'].apply(lambda x:x[2:7])
df1
# Out:
#         시점 행정구역별(1)  출생아수(명)  조출생률(천명당)  사망자수(명)  조사망률(천명당)  자연증가건수(명)  \
# 0    19.01       전국    30271        6.9    27366        6.3       2905
# 1    19.01    서울특별시     5248        6.4     3975        4.9       1273
# 2    19.01    부산광역시     1650        5.7     2161        7.5       -511
# 3    19.01    대구광역시     1253        6.0     1331        6.4        -78
# 4    19.01    인천광역시     1946        7.8     1375        5.5        571
# ..     ...      ...      ...        ...      ...        ...        ...
# 445  21.01     전라북도      739        4.9     1313        8.6       -574
# 446  21.01     전라남도      882        5.6     1564       10.0       -682
# 447  21.01     경상북도     1131        5.1     1868        8.4       -737
# 448  21.01     경상남도     1506        5.3     2034        7.2       -528
# 449  21.01  제주특별자치도      359        6.3      338        5.9         21
#
#      자연증가율(천명당)  혼인건수(건)  조혼인율(천명당)  이혼건수(건)  조이혼율(천명당)
# 0           0.7    21326        4.9     9691        2.2
# ...

# %%
df1_total = df1[df1['행정구역별(1)']=='전국']

# %%
plt.figure(figsize=(15,5))
sns.pointplot(x='시점', y='혼인건수(건)', data=df1_total)
sns.barplot(x='시점', y='이혼건수(건)', data=df1_total)
# Out:
# <AxesSubplot:xlabel='시점', ylabel='이혼건수(건)'>

# %%
plt.figure(figsize=(15,5))
#sns.barplot(x='시점', y='혼인건수(건)', data=df1_total)
sns.pointplot(x='시점', y='조혼인율(천명당)', data=df1_total)
sns.pointplot(x='시점', y='조이혼율(천명당)', data=df1_total, markers='^', color='red')
# Out:
# <AxesSubplot:xlabel='시점', ylabel='조이혼율(천명당)'>

# %%
fig, ax1 = plt.subplots(figsize=(15,5))
ax2 = ax1.twinx()
ax1 = sns.barplot(x='시점', y='이혼건수(건)', data=df1_total, ax=ax1)
ax2 = sns.pointplot(x='시점', y='조이혼율(천명당)', data=df1_total, ax=ax2)

# %%
fig, ax1 = plt.subplots(figsize=(15,5))
ax2 = ax1.twinx()
ax1 = sns.barplot(x='시점', y='혼인건수(건)', data=df1_total, ax=ax1)
ax2 = sns.pointplot(x='시점', y='조혼인율(천명당)', data=df1_total, ax=ax2)
#ax2 = sns.pointplot(x='시점', y='조이혼율(천명당)', data=df1_total, ax=ax2, markers='^', color='red')
ax1.set_xlabel('연월')
# Out:
# Text(0.5, 0, '연월')
