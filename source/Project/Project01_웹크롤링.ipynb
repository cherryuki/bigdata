# %% [markdown]
# # Project

# %% [markdown]
# ## 01. 자료수집
# ### 1) 뉴스 기사 웹크롤링
# ### 2) 식품 리포트 위주 크롤링
# - pdf파일은 어려움(txt파일 가능)
#
# ### 3) 통계청, data 위주 크롤링

# %%
#식음료신문: http://www.thinkfood.co.kr/news/articleList.html?sc_section_code=S1N1&view_type=sm
#div.list-titles > a 기사링크
#기사제목: div.list-titles > a > strong 
#기사 페이지 기사 제목: div.article-head-title
#기사 내용: article.article-veiw-body

#농수축산신문(식품): http://www.aflnews.co.kr/news/articleList.html?sc_section_code=S1N5&view_type=sm
#기사제목: h4.titles > a 텍스트
#기사 링크: h4.titles > a href
#기사 내용: #article-view-content-div

# %%
#식음료신문: http://www.thinkfood.co.kr/news/articleList.html?sc_section_code=S1N1&view_type=sm
#div.list-titles > a 기사링크
#기사제목: div.list-titles > a > strong 
#기사 페이지 기사 제목: div.article-head-title
#기사 내용: article.article-veiw-body

import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
result_df = pd.DataFrame(None, columns = ['title', 'link', 'date', 'news'])
num=1
index=0
for num in range(1, 140):
    url = 'http://www.thinkfood.co.kr/news/articleList.html?page='+str(num)+'&total=25340&sc_section_code=S1N1&sc_sub_section_code=&sc_serial_code=&sc_area=&sc_level=&sc_article_type=&sc_view_level=&sc_sdate=&sc_edate=&sc_serial_number=&sc_word=&sc_word2=&sc_andor=&sc_order_by=E&view_type=sm'
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    link_list = soup.select('div.list-titles > a')
    link_list = ['http://www.thinkfood.co.kr'+link.attrs['href'] for link in link_list]
    date_list = soup.select('div.list-dated')
    date_list = [date.text for date in date_list]
    date_list = ' '.join(date_list)
    date_list = re.findall(r'\d{4}-\d{2}-\d{2}', date_list)
    title_list = soup.select('div.list-titles > a > strong')
    title_list = [title.text for title in title_list]
    for i in range(len(link_list)):
        html = requests.get(link_list[i])
        news_soup = BeautifulSoup(html.content, 'html.parser')
        news_list = news_soup.select('article.article-veiw-body')
        news_list = [news.text for news in news_list]
        result_df.loc[index] = [title_list[i], link_list[i], date_list[i], news_list]
        index+=1
    num+=1

# %%
result_df.to_csv('01_식음료신문.csv', sep=',')

# %%
#농수축산신문(식품): http://www.aflnews.co.kr/news/articleList.html?page=1&total=5118&box_idxno=&sc_section_code=S1N5&view_type=sm
#기사제목: h4.titles > a 텍스트
#기사 링크: h4.titles > a href
#기사 내용: #article-view-content-div

import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
result_df = pd.DataFrame(None, columns = ['title', 'link', 'date', 'news'])
num=1
index=0
for num in range(2):
    url = 'http://www.aflnews.co.kr/news/articleList.html?page='+str(num)+'&total=5118&box_idxno=&sc_section_code=S1N5&view_type=sm'
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    link_list = soup.select('h4.titles > a')
    link_list = ['http://www.aflnews.co.kr'+link.attrs['href'] for link in link_list]
    title_list = soup.select('h4.titles > a')
    title_list = [title.text for title in title_list]
    date_list = soup.select('span.byline')
    date_list = [date.text for date in date_list]
    date_list = ' '.join(date_list)
    date_list = re.findall(r'\d{4}.\d{2}.\d{2}', date_list)
    for i in range(len(link_list)):
        html = requests.get(link_list[i])
        news_soup = BeautifulSoup(html.content, 'html.parser')
        news_date = news_soup.select_one('i.icon-clock-o')
        news_list = news_soup.select('article#article-view-content-div')
        news_list = [news.text for news in news_list]
        result_df.loc[index] = [title_list[i], link_list[i], date_list[i], news_list]
        index+=1
    num+=1

# %%
result_df.to_csv('02_농수축산신문.csv', sep=',')

# %%
news_list
# Out:
# []

# %%
result_df
# Out:
#                                  title  \
# 0                        봄나들이 대신 미식 여행
# 1   지난해 식품 수입 전년대비 금액 0.5%, 물량 0.6% 감소
# 2             즉석제조식품, 자동판매기 통한 판매 시범허용
# 3              2021년 직거래장터 지원사업 대상자 모집
# 4              김강립 식약처장, 소비자단체와 간담회 개최
# 5                  식품연, 해외인증등록 참여업체 모집
# 6               한식 전문인력 양성기관 지정 신청하세요!
# 7    aT, 중소농식품기업·소상공인 규제 개선·애로사항 해소 앞장
# 8       '쌀가공품 품평회' 개최...4월 2일까지 온라인 접수
# 9             한국농식품법인연합회장에 강 용 학사농장 대표
# 10            김영재 한국식품산업클러스터진흥원 이사장 취임
# 11             [기획] 농식품 수출 80억 달러 돌파하나
# 12                 소비자 68.9% 건강기능식품 섭취
# 13             박석배 aT 감사, 수산업계 애로사항 청취
# 14          서울장수, 15년 만에 장수 생막걸리 가격 인상
# 15                 부산 ‘국제식품박람회’ 11일 개막
# 16            2021년 식품안전나라 대국민 수요조사 실시
# 17                김치어워즈 개최로 종주국 위상 높인다
# 18      (사)한국식품콜드체인협회, 콜드체인전문가 양성과정 개설
# 19         식약처, 신중년 맞춤형 식사관리 안내서 제작·배포
# 20
# 21                       봄나들이 대신 미식 여행
# 22  지난해 식품 수입 전년대비 금액 0.5%, 물량 0.6% 감소
# 23            즉석제조식품, 자동판매기 통한 판매 시범허용
# 24             2021년 직거래장터 지원사업 대상자 모집
# 25             김강립 식약처장, 소비자단체와 간담회 개최
# 26                 식품연, 해외인증등록 참여업체 모집
# 27              한식 전문인력 양성기관 지정 신청하세요!
# 28   aT, 중소농식품기업·소상공인 규제 개선·애로사항 해소 앞장
# 29      '쌀가공품 품평회' 개최...4월 2일까지 온라인 접수
# 30            한국농식품법인연합회장에 강 용 학사농장 대표
# 31            김영재 한국식품산업클러스터진흥원 이사장 취임
# 32             [기획] 농식품 수출 80억 달러 돌파하나
# 33                 소비자 68.9% 건강기능식품 섭취
# 34             박석배 aT 감사, 수산업계 애로사항 청취
# 35          서울장수, 15년 만에 장수 생막걸리 가격 인상
# 36                 부산 ‘국제식품박람회’ 11일 개막
# 37            2021년 식품안전나라 대국민 수요조사 실시
# 38                김치어워즈 개최로 종주국 위상 높인다
# 39      (사)한국식품콜드체인협회, 콜드체인전문가 양성과정 개설
# 40         식약처, 신중년 맞춤형 식사관리 안내서 제작·배포
# 41
#
#                                                  link news
# 0   http://www.aflnews.co.kr/news/articleView.html...   []
# 1   http://www.aflnews.co.kr/news/articleView.html...   []
# 2   http://www.aflnews.co.kr/news/articleView.html...   []
# 3   http://www.aflnews.co.kr/news/articleView.html...   []
# 4   http://www.aflnews.co.kr/news/articleView.html...   []
# 5   http://www.aflnews.co.kr/news/articleView.html...   []
# 6   http://www.aflnews.co.kr/news/articleView.html...   []
# 7   http://www.aflnews.co.kr/news/articleView.html...   []
# 8   http://www.aflnews.co.kr/news/articleView.html...   []
# 9   http://www.aflnews.co.kr/news/articleView.html...   []
# 10  http://www.aflnews.co.kr/news/articleView.html...   []
# 11  http://www.aflnews.co.kr/news/articleView.html...   []
# 12  http://www.aflnews.co.kr/news/articleView.html...   []
# 13  http://www.aflnews.co.kr/news/articleView.html...   []
# 14  http://www.aflnews.co.kr/news/articleView.html...   []
# 15  http://www.aflnews.co.kr/news/articleView.html...   []
# 16  http://www.aflnews.co.kr/news/articleView.html...   []
# 17  http://www.aflnews.co.kr/news/articleView.html...   []
# 18  http://www.aflnews.co.kr/news/articleView.html...   []
# 19  http://www.aflnews.co.kr/news/articleView.html...   []
# 20                           http://www.aflnews.co.kr   []
# 21  http://www.aflnews.co.kr/news/articleView.html...   []
# 22  http://www.aflnews.co.kr/news/articleView.html...   []
# 23  http://www.aflnews.co.kr/news/articleView.html...   []
# 24  http://www.aflnews.co.kr/news/articleView.html...   []
# 25  http://www.aflnews.co.kr/news/articleView.html...   []
# 26  http://www.aflnews.co.kr/news/articleView.html...   []
# 27  http://www.aflnews.co.kr/news/articleView.html...   []
# 28  http://www.aflnews.co.kr/news/articleView.html...   []
# 29  http://www.aflnews.co.kr/news/articleView.html...   []
# 30  http://www.aflnews.co.kr/news/articleView.html...   []
# 31  http://www.aflnews.co.kr/news/articleView.html...   []
# 32  http://www.aflnews.co.kr/news/articleView.html...   []
# 33  http://www.aflnews.co.kr/news/articleView.html...   []
# 34  http://www.aflnews.co.kr/news/articleView.html...   []
# 35  http://www.aflnews.co.kr/news/articleView.html...   []
# 36  http://www.aflnews.co.kr/news/articleView.html...   []
# 37  http://www.aflnews.co.kr/news/articleView.html...   []
# 38  http://www.aflnews.co.kr/news/articleView.html...   []
# 39  http://www.aflnews.co.kr/news/articleView.html...   []
# 40  http://www.aflnews.co.kr/news/articleView.html...   []
# 41                           http://www.aflnews.co.kr   []

# %%
[date.text for date in news_date]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-313170fcdb60> in <module>
# ----> 1 [date.text for date in news_date]
#
# TypeError: 'NoneType' object is not iterable
